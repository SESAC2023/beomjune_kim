# %%
# !pip install transformers
# !pip install datasets #데이터 세트 다운로드 Hugging Face 연동
# Out:
# Collecting transformers
#   Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.2-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 120.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.2 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.2
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.17.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.14.5 dill-0.3.7 multiprocess-0.70.15 xxhash-3.3.0

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
import copy # 특정한 파이썬 객체를 통째로 메모리에 copy할 때
import json # json 형식으로 데이터를 표현할 때
import logging # 학습 과정 등 전반적인 프로그램의 진행 상황을 로깅할 때
import os # 파일 입출력 등 현재 컴퓨터에 대한 기능 수행할 때

# 경고(warning) 메시지가 너무 많이 나오는 것을 대비하여 무시 처리
import warnings
warnings.filterwarnings("ignore")

# 로깅할 때 기본적으로 오류(error) 사항으로 로그 메시지를 남기겠다는 의미
import logging
logging.basicConfig(level=logging.ERROR)

# 벡터, 행렬 등의 처리를 위한 NumPy, 테이블(엑셀) 형식의 데이터 처리할 때 Pandas
import numpy as np
import pandas as pd

from datasets import load_dataset
# train_test_split: 별도로 구분된 validation 세트가 없을 때
# 학습 데이터 세트에서 일부를 train과 validation으로 나눌 때 자주 사용 (8:2 정도로 나눔)
from sklearn.model_selection import train_test_split
from tqdm import tqdm

import torch

# %% [markdown]
# ### 학습한 모델 관련 라이브러리 불러오기

# %%
import transformers
# Auto Model For Sequence Classification: 텍스트 분류를 위한 모델 → Cross-Entropy loss 사용
from transformers import AutoConfig, AutoModel, AutoModelForSequenceClassification, AutoTokenizer
# linear_schedule_with_warmup: 단계적으로 learning rate 줄여나가는 방법
# AdamW: SGD와 같이 optimization 방법 중 하나
from transformers import AdamW, get_linear_schedule_with_warmup

# %% [markdown]
# ### 우리가 쓸 모델
#
# - KoBigBird를 사용하고, 다음과 같은 형태로 사용 가능
# - KoBigBird: BigBird 특유의 sparse attention 사용 (default)

# %%
from transformers import AutoModel, AutoTokenizer

# by default its in `block_sparse` mode with num_random_blocks=3, block_size=64
# 이름에서부터 알 수 있듯이 KoBigBird는 BERT 기반의 모델
model = AutoModel.from_pretrained("monologg/kobigbird-bert-base")

# Tokenizer도 마찬가지로 BERT 기반에서 가져온 것을 확인
tokenizer = AutoTokenizer.from_pretrained("monologg/kobigbird-bert-base")
text = "한국어 BigBird 모델을 공개합니다!"
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/870 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/458M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/241k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/492k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/169 [00:00<?, ?B/s]
# Attention type 'block_sparse' is not possible if sequence_length: 12 <= num global tokens: 2 * config.block_size + min. num sliding tokens: 3 * config.block_size + config.num_random_blocks * config.block_size + additional buffer: config.num_random_blocks * config.block_size = 704 with config.block_size = 64, config.num_random_blocks = 3. Changing attention type to 'original_full'...

# %% [markdown]
# ### 실험을 위한 하이퍼 파라미터 설정

# %%
# SimpleNamespace는 온점(.)으로 속성의 값을 정의할 수 있도록 해주는 라이브러리
# config.task = "cls"라고 하면, 나중에 print(config.task)했을 때 "cls"라고 출력
from types import SimpleNamespace

config = SimpleNamespace()

config.task = "cls"
config.dataset = "comment"

config.cache_dir = "cache" # 현재 데이터 세트에 대한 단어집 등 현재 task를 위한 임시적인 폴더
config.output_dir = "output" # 최종적인 모델이 저장되고, 결과가 저장되는 폴더

config.use_tpu = False
config.model_name_or_path = "monologg/kobigbird-bert-base" # Model name or path (HuggingFace에서 불러와 사용할 모델 이름)
config.data_dir = "./" # The input data dir ("10000_labeled.csv"가 있는 경로)


config.train_file = "complete_train.csv" # 미리 준비된 학습 데이터 세트 경로
config.test_file = "complete_test.csv" # 미리 준비된 평가 데이터 세트 경로

config.max_seq_length = 1024 # The maximum total input sequence length after tokenization. (최대 토큰 길이)
config.train_batch_size = 4 # Batch size for training. (학습할 때 batch_size)
config.eval_batch_size = 2 # Batch size for evaluation. (평가할 때 batch_size)

config.learning_rate = 3e-5 # The initial learning rate for Adam. (Adam optimizer에서 쓸 learning rate)
config.num_train_epochs = 20 # Total number of training epochs to perform. (전체 학습 epoch 수)

config.num_labels = 5 # 현재 task에서 선호도(1: 극진보, 2: 진보, 3: 중립, 4: 보수, 5: 극보수)의 개수는 5개이므로
# 5 classes multi-class classification 문제로 이해 할 수 있음
config.gradient_accumulation_steps = 2 # Number of updates steps to accumulate before performing a backward/update pass.
# batch_size가 큰 것처럼 처리하기 위해서, backward()를 매 번 수행하지 않고, gradient를 누적(acculmulation)하는 것

config.threads = 4
config.seed = 42 # random seed for initialization

config.do_train = True # Whether to run training.
config.do_eval_during_train = True
config.do_eval = True # Whether to run prediction.

config.do_lower_case = False
config.weight_decay = 0.0 # Weight decay if we apply some.
config.adam_epsilon = 1e-8 # Epsilon for Adam optimizer.
config.max_grad_norm = 1.0 # Max gradient norm.
config.warmup_proportion = 0.0 # Warmup proportion for linear warmup
# BigBird에서는 full attention을 하면, 메모리는 조금 더 소모되지만, 더 정확도가 향상
# config.attention_type = "original_full"

# %% [markdown]
# ### 학습 데이터 전처리
# - 학습 text를 매번 tokenization을 하지 않고, 모델 학습 시작전에 미리 모든 텍스트를 tokenization 한 결과를 저장한다.

# %%
# 본 실습에서 사용할 tokenizer 객체 초기화
tokenizer = AutoTokenizer.from_pretrained(config.model_name_or_path, cache_dir=config.cache_dir)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/241k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/492k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/169 [00:00<?, ?B/s]

# %%
def train_split(config, texts, labels, is_train):
    if is_train:
        x_train, x_val, y_train, y_val = train_test_split(
            texts, labels, test_size=500, random_state=config.seed, stratify=None
        )
        return x_train, y_train, x_val, y_val
    else:
        return texts, labels

# %%
import pandas as pd
import os
import json
from sklearn.model_selection import train_test_split

# 데이터 전처리 및 분리 함수
def process_and_split_dataset(config, data_file):
    is_train = True if 'train' in data_file else False

    df = pd.read_csv(data_file)
    df = df.dropna(subset=['title', 'content', 'label2'])

    # "label2" 열 추출
    government = (df["label2"]).astype(int).values.tolist()

    # title과 content를 합쳐서 texts로 표현
    texts = (df["title"].str.replace('\n', ' ') + " " + df["content"].str.replace('\n', ' ')).astype(str).values.tolist()

    # 데이터를 학습 및 검증용으로 분할
    return train_split(config, texts, government, is_train)

def data_pretokenizing(config, tokenizer, mode="train"):
    # 파일 경로 설정
    data_path = os.path.join(config.data_dir, config.train_file if mode == "train" else config.test_file)
    processed_data = process_and_split_dataset(config, data_path)

    datasets = {}
    if mode == "train":
        train_data_texts, train_data_labels, valid_data_texts, valid_data_labels = processed_data
        datasets["train"] = (train_data_texts, train_data_labels)
        datasets["valid"] = (valid_data_texts, valid_data_labels)
    else:  # mode == "test"
        test_data_texts, test_data_labels = processed_data
        datasets["test"] = (test_data_texts, test_data_labels)

    dataset_files = {}
    for key, (texts, labels) in datasets.items():
        # 데이터 파일명 설정
        dataset_file = os.path.join(config.data_dir, f"{config.dataset}_{config.model_name_or_path.replace('/', '_')}_{config.max_seq_length}_{key}_dataset.txt")
        print("dataset_file:", dataset_file)

        with open(dataset_file, "w", encoding="utf-8") as writer_file:
            for text, label in zip(texts, labels):
                print(f"Processing text: {text[:50]}...")  # 첫 50자만 출력
                print(f"Processing label: {label}")

                feature = tokenizer(text, max_length=config.max_seq_length, padding="max_length", truncation=True, add_special_tokens=True)

                writed_data = {
                    "input_ids": feature["input_ids"],
                    "attention_mask": feature["attention_mask"],
                    "government": label  # 'politic'을 'government'로 변경
                }
                writer_file.write(json.dumps(writed_data) + "\n")

        dataset_files[key] = dataset_file

    return dataset_files

# %%
# 학습 및 검증 데이터 토큰화
train_valid_files = data_pretokenizing(config, tokenizer=tokenizer, mode="train")
train_dataset_file = train_valid_files["train"]
valid_dataset_file = train_valid_files["valid"]

# 테스트 데이터 토큰화
test_files = data_pretokenizing(config, tokenizer=tokenizer, mode="test")
test_dataset_file = test_files["test"]
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Processing text: 돈봉투 의혹' 윤관석·이성만, 당내 압박에 결국 자진탈당 지난 2021년 더불어민주당 전당...
# Processing label: 0
# Processing text: 노량진 수산시장 상인 “집회꾼들, 같이 시위하자고 계속 전화... 딱 잘라 거절” 2023...
# Processing label: 0
# Processing text: 김웅 "김재원의 '조상묘 파기'겠죠"…김재원, 5.18묘지 기습 참배에 반응 '싸늘' 김재...
# Processing label: 0
# Processing text: KBS 노동조합, 남영진 이사장 '청탁금지법 위반' 권익위 고발 KBS 노동조합은 13일 ...
# Processing label: 0
# Processing text: 내년 5월까지 손묶인 홍준표 "발언권은 살아 있다…내겐 3년의 긴 시간이"         ...
# Processing label: 0
# Processing text: "9사단 지휘부 16첩 반상 호화파티…사병들 앓아눕기도"         임태훈 군인권센터 ...
# Processing label: 2
# Processing text: 이번엔 '국회 간첩' 논란…국민의힘 “민주 보좌관 전수조사하라” 설훈 더불어민주당 의원실에...
# Processing label: 0
# Processing text: 이재명 “환자에 헌신한 故주석중 교수 명복 빈다” 18일 오후 서울아산병원 장례식장에 고 ...
# Processing label: 0
# Processing text: ‘스토킹 방지법’ 국회 본회의 통과... 피해자가 원하지 않아도 처벌 김진표 국회의장이 2...
# Processing label: 0
# Processing text: 서복경 혁신위원 "당원 200만, 늘어난 몸집 맞는 시스템 찾는 중"         서복경...
# Processing label: 0
# Processing text: 국회 윤리특위, '김남국 심사' 1소위 배정…"8월 본회의 상정 원칙"         변재...
# Processing label: 0
# Processing text: 야당 의원 95명 연명 "에너지공대 정치탄압 중단해야"         신정훈 의원(나주·화...
# Processing label: 1
# Processing text: [오늘의 국회일정](31일, 월)         국회 본회의장 2023.7.27/뉴스1 ©...
# Processing label: 3
# Processing text: 안철수 “후쿠시마 오염수, 과학적으로 문제 없어도 국민 설득해야” 안철수 국민의힘 의원은 ...
# Processing label: 0
# Processing text: "잘못 없다"던 홍준표, 수해골프 당 진상조사 시작되자 "송구" 홍준표 대구시장이 지난 1...
# Processing label: 2
# Processing text: 이동관 청문회 앞두고…여 "의무 팽개치고 정쟁" 야 "언론장악 본색"         이동관...
# Processing label: 0
# Processing text: 이재명 "여야, 조속한 추경 노력해야…정부여당에 간곡 요청"         이재명 더불어민...
# Processing label: 1
# Processing text: 민주당, 의총서 ‘불체포특권 포기’ 결의…불발 닷새 만에 박광온 원내대표를 비롯한 더불어민...
# Processing label: 0
# Processing text: 민주당 방탄포기 제동…혁신위 ‘1호안’부터 표류 더불어민주당이 13일 의원총회에서 혁신위원...
# Processing label: 0
# Processing text: 북한, '체육 우표'도 발행…스포츠 열풍 분위기 이어가         (평양 노동신문=뉴스...
# Processing label: 0
# Processing text: 尹대통령 직속 1호' 국민통합위, 오는 27일 출범 1주년 대통령 직속 국민통합위원회(위원...
# Processing label: 4
# Processing text: 김원웅이 실추시킨 광복회, 새 회장에 이종찬·장호권 양강 구도 지난 4년간 ‘정치 편향’ ...
# Processing label: 0
# Processing text: G7 맞춰 떠오른 비밀병기… 美 전략핵잠 42년만에 부산 오나 미국 인도태평양사령부가 지난...
# Processing label: 0
# Processing text: “낙지탕탕이” “똥파리”…혐오·비하 넘치는 이재명표 ‘블루웨이브’ 이재명 더불어민주당 대표...
# Processing label: 0
# Processing text: 확장억제 결핍 착각증세'를 치유하자 4월 26일 한미정상회담을 앞두고 '확장억제'가 어떻게...
# Processing label: 1
# Processing text: ‘김건희 의혹’ 확산 막겠다며 ‘지역 숙원’ 양평고속도로 백지화 원희룡 국토교통부 장관이 ...
# Processing label: 2
# Processing text: 한·일·호주·뉴질랜드 정상 “北 탄도미사일 규탄” 공동성명 윤석열 대통령을 비롯해 기시다 ...
# Processing label: 3
# Processing text: 이재명, 김기현 아들 코인 논란에 "가상자산 운운하더니 후안무치" 이재명 더불어민주당 대표...
# Processing label: 0
# Processing text: 한국 국회의원 독도 방문에 일본 강한 유감표명 더불어민주당 전용기 의원의 독도 방문을 두고...
# Processing label: 0
# Processing text: 尹 ”유엔사, 후방기지 확보 플랫폼“…자갈치 시장선 ”현명한 국민, 괴담에 안 흔들려“ 윤...
# Processing label: 4
# Processing text: 中 눈치보며 사드 미룬 文정부…美, 동맹관계 맞나 의심했다 문재인 정부가 사드(THAADㆍ...
# Processing label: 4
# Processing text: 군 검찰, '군사기밀 유출 혐의' 부승찬 전 국방부 대변인 기소 부승찬 전 국방부 대변인이...
# Processing label: 3
# Processing text: 이화영 부인 "고립된 남편, 심리적 압박"…檢 "변호인 180회 접견" 검찰이 이화영 전 ...
# Processing label: 0
# Processing text: 민주 "대통령 친인척비리 극복 위해 특별감찰관 임명 전면쇄신을“         이재명 더불...
# Processing label: 1
# Processing text: [단독] 이낙연 '강연정치' 나선다…호남·부산 찾아 본격 행보        이낙연 전 더불...
# Processing label: 0
# Processing text: ‘천공’ 의혹 제기 부승찬 “국방부, 권력의 개 되지 마라” 부승찬 전 국방부 대변인이 2...
# Processing label: 2
# Processing text: 김은경 "마음 상하게 한 것 죄송"…노인회장, 사진 때리며 질타         김은경 더불...
# Processing label: 0
# Processing text: 김정은 "화성-18형 입네다"…美 보란듯 쇼이구에 무기 가이드 김정은 국무위원장이 26일 ...
# Processing label: 2
# Processing text: 기술력까지 갖춘 中기세에 눌렸다…'넘사벽' 美조선업의 굴욕[이철재의 밀담] 이달 미국의 유...
# Processing label: 4
# Processing text: 금태섭 "9월 창당 박차…뜻 같이 하는 사람들과 협력" 추석 전 신당 창당을 공언했던 금태...
# Processing label: 0
# Processing text: 장경태 "인간적 모멸감 무릅쓰고 풀영상 공개한다…장예찬, 근거 대보라" 장경태 더불어민주당...
# Processing label: 0
# Processing text: 민주당 "오염수 결의안 처리, 이태원 특별법 패스트트랙 돌입" 예고 더불어민주당이 오는 3...
# Processing label: 0
# Processing text: 尹, 기시다 日 총리 만나 후쿠시마 오염수 논의 예정…대통령실 “자연재해. 아시아 국가 고...
# Processing label: 3
# Processing text: 발끈'한 홍준표 "난 킬리만자로 표범, 너희들처럼 쥐떼 정치 안했다" 최근 국민의힘 지도부...
# Processing label: 2
# Processing text: 돈봉투' 파장에 민주당 원내대표 선거 구도 급변 더불어민주당 원내대표 선거 지형에 변화가 ...
# Processing label: 0
# Processing text: 유승민 "카르텔? 검사가 룸살롱에서 술마셨는데 징계 안해, 그게 카르텔" 윤석열 대통령이 ...
# Processing label: 1
# Processing text: 윤여준 "이재명, 연말 못 넘길 듯…김기현, 국감 존재감 없다면 힘들다"         김...
# Processing label: 0
# Processing text: 與 '日오염수' 국민 대토론회…전문가 "6000억년 노출돼야 기준치 초과" 5일 국회에서 ...
# Processing label: 5
# Processing text: 원희룡·한동훈·박민식 선봉에 섰다…윤 대통령 엄호·보수 결집        왼쪽부터 원희룡 ...
# Processing label: 5
# Processing text: 美 '대만 군사지원 발표' 뒤 中 왕이 초청… 갈등 관리 지속        왕이 중국 외교...
# Processing label: 2
# Processing text: “러 바그너 사태, 김정은엔 악몽…北 전복 영감 줄수도” 최근 러시아의 용병기업인 바그너그...
# Processing label: 0
# Processing text: 5·18 기념식에 與野 총집결… 총선 1년 앞두고 ‘호남 민심 잡기’ 17일 오후 광주 동...
# Processing label: 4
# Processing text: 삿대질 대신 기립박수 보냈다, 김예지의 ‘물고기 연설’ 한동훈 법무장관에 질의하는 시각장애...
# Processing label: 0
# Processing text: 유병호의 파격 인사…1년만에 감사원 국장 오른 김숙동, 누구 감사원이 12일 7급 감사직 ...
# Processing label: 3
# Processing text: 野 "아들 '학폭가해'가 尹정권에선 공직 임명 가산점인가" 차기 방송통신위원장으로 이동관 ...
# Processing label: 1
# Processing text: 與 "오염수 반대 단체, 광우병 대책위와 사실상 같은 인적 구성" 국민의힘 시민단체선진화특...
# Processing label: 0
# Processing text: 尹, 나토 동맹국 정상회의서 "北미사일, 파리·런던도 타격 가능" 윤석열 대통령은 12일(...
# Processing label: 3
# Processing text: 민주당 ‘방탄불패’... 이재명 체제 뒤 野 4연속 체포안 부결 더불어민주당 전당대회 돈 ...
# Processing label: 0
# Processing text: 野 이상민 “이래경 사태는 이재명의 본질적 결함, 당대표 사퇴해야” 더불어민주당 이상민 의...
# Processing label: 0
# Processing text: 尹대통령 “신짜오” 인사에 베트남 학생들 기립박수 윤석열 대통령이 22일 베트남에서 현지인...
# Processing label: 3
# Processing text: “ICBM 우려” ARF 성명…유엔 총회에 최선희 불참 가능성도 안광일 북한 주인도네시아 ...
# Processing label: 0
# Processing text: 제인 구달 "반려견은 내 스승"…김건희 여사 "개식용 종식 노력" 윤석열 대통령의 부인 김...
# Processing label: 0
# Processing text: "IAEA 보고서 겸허히 수용? 우리가 잘못 저질렀나?"…'후쿠시마 총공세' 나선 野 더불...
# Processing label: 2
# Processing text: 공수처, '김학의 무혐의' 검사들 수사 착수…공소시효는 오는 11월 11일 고위공직자범죄수...
# Processing label: 3
# Processing text: JP 빤히 보던 관상가 백운학…대뜸 외쳤다 “됩니다, 혁명!” (8) 「 시운(時運)은 대...
# Processing label: 0
# Processing text: 우리 예비교사들, 캐나다서 '6·25전쟁 교육 활성화' 논의         캐나다 교육자료...
# Processing label: 0
# Processing text: 여야, 수신료 분리 징수·선거제 개혁 등 논의했지만 '빈손' 국회 교섭단체 원내대표들이 한...
# Processing label: 0
# Processing text: 참전용사 후손 등 육군 부사관 352명 임관… 국방장관 주관 처음        (육군 제공...
# Processing label: 3
# Processing text: [단독]野혁신위, 상임고문단과 회동…불체포특권 포기 압박할 듯 더불어민주당 혁신위원회가 이...
# Processing label: 0
# Processing text: 박지원 “尹이 나를 현실정치로 몰아” 손혜원 “별 추접스런 핑계” 박지원 전 국정원장(왼쪽...
# Processing label: 2
# Processing text: 김병욱 "조국 일가 위선적인 반성, 법 심판 모면하려는 '악어의 눈물'" 국회 교육위원회 ...
# Processing label: 0
# Processing text: 작년 림팩훈련 SM-2 공중서 '펑'…"원인은 소프트웨어 오류" 지난해 7월 환태평양훈련(...
# Processing label: 3
# Processing text: 두 달만에 온 B-52H… 핵잠수함도 온다 미국 B-52H 폭격기(가운데)와 공군 F-16...
# Processing label: 3
# Processing text: 대통령실 "내달 美서 한미일 정상회담…구체 시기·장소 곧 발표" 한국·미국·일본 정상이 오...
# Processing label: 4
# Processing text: 그로시 "방류 아닌 다른 방법? 세계를 '실험실 쥐'로 만들건가" 라파엘 그로시(62) 국...
# Processing label: 3
# Processing text: 원희룡 "백지화" 그날, 尹지지율 7.6%P 하락…與 "역풍 걱정" “시간이 지나면 결국 ...
# Processing label: 0
# Processing text: 한층 더 심화된 '한미일 vs 북중러'… 한반도 신냉전 가시화        (평양 노동신문...
# Processing label: 3
# Processing text: 윤 대통령, 이르면 이번주 방통위원장 지명할 듯…후속 개각 '촉각'         윤석열 ...
# Processing label: 5
# Processing text: 이재명 "인수위 1호 과제가 대통령 처가 특혜…'양평' 국정조사 하자" 이재명 더불어민주당...
# Processing label: 1
# Processing text: "위조"됐다는 미국 문건, 정작 외교부 장관은 "확인한 바 없어" 미국 기밀 문건 유출과 ...
# Processing label: 1
# Processing text: 전승절' 앞둔 북한 "국가방위력 무한대로 끌어올려야" 북한이 ‘전승절’로 부르는 정전협정 ...
# Processing label: 0
# Processing text: 감사원 "환경부 일회용컵 보증금제 규정 늦어져 가맹점주 혼란"         컵가디언즈, ...
# Processing label: 0
# Processing text: 박광온 두달, 이재명과 투톱 구축…‘말길’ 열렸지만 대여투쟁 흐릿 박광온 더불어민주당 원내...
# Processing label: 0
# Processing text: 한미 핵협의그룹 차관급 격상... 이달 서울서 열릴 듯 한미 안보 당국이 지난 4월 워싱턴...
# Processing label: 3
# Processing text: 이재명 " IAEA 발표, 검증조차 안 된 결과…국민 불안 현실로" 이재명 더불어민주당 대...
# Processing label: 1
# Processing text: 진중권, 윤 정부 첫 개각 두고 "유튜버들에 희망 주는 훌륭한 인사" 진중권 광운대 특임교...
# Processing label: 1
# Processing text: 국힘, 8월3일 '당무감사' 공고…10월 시작, 이르면 11월 마무리         신의진...
# Processing label: 0
# Processing text: 文정부 통계조작 의혹' 김수현 조사…감사원, 장하성도 곧 소환 문재인 정부의 통계조작 의혹...
# Processing label: 3
# Processing text: [단독] 文때 보훈처 “윗집 오더다”… 호국영웅을 반민족 친일파로 낙인 정부는 고(故) 백...
# Processing label: 4
# Processing text: [단독] 6·25영웅 백선엽 ‘친일파’ 문구 지웠다...“文정부, 법적 근거 없이 기재” ...
# Processing label: 4
# Processing text: 정부 “IAEA 결론 존중”… 野는 “일본 맞춤형 용역 보고서 수준” 정부는 5일 일본의 ...
# Processing label: 3
# Processing text: 북한, 중국 중고 선박 올해만 20척째 구매 정황…"제재 위반"         자료사진. ...
# Processing label: 0
# Processing text: 국힘, 김은경 사과에 "자리보전용…이재명 직접 사과해야"         김은경 더불어민주당...
# Processing label: 0
# Processing text: 북한 “미 정찰기, 영공 침범” 하루 두 차례 경고 김여정 북한 노동당 부부장이 10일 미...
# Processing label: 0
# Processing text: 오염수 방류 또 충돌…與 "뭘 더 해야하나" vs 野 "日 대변하나" 다음달 방류가 시작될...
# Processing label: 3
# Processing text: 국힘, 민주 보좌진 국보법 위반 혐의에 "대국민 사과하라"         한기호 국회 국방...
# Processing label: 0
# Processing text: 유인태 "이낙연, 이재명과 막걸리 놓고 허심탄회하게 앙금 풀라" 더불어민주당 원로인 유인태...
# Processing label: 0
# Processing text: 윤석열 정부의 미중외교, “고래싸움에 새우가 칼부림” [공덕포차] 지난 19일, 토니 블링...
# Processing label: 1
# Processing text: 권영준·서경환 임명동의안 통과, 대법 중도·보수 7 진보 6 구도로 권영준(53·사법연수원...
# Processing label: 4
# Processing text: 김기현 “국내 중국인 투표권 제한…건보 ‘먹튀’도 막겠다” 김기현 국민의힘 대표가 20일 ...
# Processing label: 0
# Processing text: 통일미래기획위원장에 이정훈 이정훈(62·사진) 연세대 국제대학원 교수가 10일 신임 통일미...
# Processing label: 3
# Processing text: 민주, 이상민 탄핵 기각에 “책임 물을 수도 없다, 참담한 심정” 더불어민주당은 25일 헌...
# Processing label: 2
# Processing text: [유용원의 밀리터리 시크릿] 尹정부 외교안보 1년...당당한 외교와 건강한 한중관계 조태용...
# Processing label: 4
# Processing text: 북한판 글로벌호크·리퍼' 나왔다…北 '정찰·타격 능력' 과시        (평양 노동신문=...
# Processing label: 2
# Processing text: 이재명, 김기현 당대표 누가 잘하나…여론조사 보니 '도긴개긴' 여야 정당 대표에 대한 유권...
# Processing label: 0
# Processing text: 이준석 "수능 관련해 질렀다가 강사들 악마화, 전략적으로 바보 행동" 이준석 전 국민의힘 ...
# Processing label: 1
# Processing text: 與 "그 풍수전문가, 김정숙∙이재명도 만났다…'주술 프레임' 졸렬" 지난해 대통령 관저 선...
# Processing label: 4
# Processing text: 한덕수 "초등 5학년 영어 문제 보니, 저도 못 풀겠더라" 한덕수 국무총리가 최근 수능 '...
# Processing label: 4
# Processing text: 美 "내달 18일 한미일 정상회의"…대통령실 "중요한 전기"(종합2보)         윤석...
# Processing label: 5
# Processing text: 장제원, '불출마설' 일축 "하늘 두 쪽 나도 총선 출마한다" 윤석열 대통령의 최측근으로 ...
# Processing label: 0
# Processing text: ‘갓 탤런트’ 우승한 英 참전용사, 부산서 전우 위한 아리랑 부른다 콜린 태커리(93) 씨...
# Processing label: 0
# Processing text: IAEA 사무총장 방한 날, '오염수 반대' 랩핑 버스 띄운 野 더불어민주당이 라파엘 그로...
# Processing label: 3
# Processing text: 野 "아버지를 아버지라 못 부르고, 오염수를 오염수라 못 부르고?" 후쿠시마 원전 오염수에...
# Processing label: 1
# Processing text: 北 '전승절' 70주년… 이번에도 평양서 야간 열병식 진행        (평양 노동신문=뉴...
# Processing label: 0
# Processing text: 미래 전장에선 드론으로 통신 지원… "다계층 통합 네트워크 구축"         정찰 드론...
# Processing label: 3
# Processing text: 국힘 조강특위 오늘 면접 마무리…이르면 내주 조직위원장 확정        왼쪽부터 배현진 ...
# Processing label: 0
# Processing text: 尹 "과학, 자유 지키는데 가장 중요"…한인 과학기술인 대회 방문 윤석열 대통령은 5일 ‘...
# Processing label: 3
# Processing text: “사전보고 안해” 말바꾼 이화영...與 “이재명과 범죄궁합 기막혀” 2018년 7월 10일...
# Processing label: 0
# Processing text: 삼성폰인 줄..."전자파 주의" 北최신 스마트폰 '삼태성8' 포착 북한의 최신 스마트폰 ‘...
# Processing label: 0
# Processing text: "北과 바로 맞서는게 천직" 오늘도 수색대는 지뢰밭에 삶 던진다 [정전 70년 한미동맹 7...
# Processing label: 4
# Processing text: 2만 청년, 6·25전쟁 피란수도 부산을 달린다'         (국가보훈부 제공)    ...
# Processing label: 3
# Processing text: 한반도 평화에 누가 중요? 미국 70%, 중국 20%, 일본 3% [갤럽] ‘정전 70년 ...
# Processing label: 0
# Processing text: 이동관도 '내로남불' 논란…과거 "전화 함부로 하면 안돼", "부모는 자식의 거울" 방송통...
# Processing label: 1
# Processing text: [이번 주 리뷰] 해병대원ㆍ교사의 안타까운 죽음…NCG, ”北 핵도발은 정권종말”(17~2...
# Processing label: 5
# Processing text: 2013년 미국 '베팅'은 감싸더니 이번 중국 '베팅'은 유감표명? 정부가 싱하이밍(邢海明...
# Processing label: 2
# Processing text: 홍준표 “퀴어축제 도로점거 막겠다니 경찰이 ‘집회방해’ 엄포… 공권력 나약, 걱정” 홍준표...
# Processing label: 3
# Processing text: 박광온 "대통령 말 한마디에 수능 대혼란, 대국민 사과해야" 박광온 더불어민주당 원내대표는...
# Processing label: 1
# Processing text: 보안 점검조차 거부하더니… 선관위 해킹 시도 작년에만 4만건 중앙선거관리위원회에 대한 북한...
# Processing label: 3
# Processing text: 유엔도 북핵 제재 못한다…신냉전 구도 강해지며 기능 상실 합동참모본부는 지난 15일 오후 ...
# Processing label: 0
# Processing text: 홍준표 '당원권 정지 10개월', 내년 총선까지 정치활동 봉쇄? 국민의힘이 홍준표 대구시장...
# Processing label: 2
# Processing text: 무단 월북 미군, 북미 관계 변화 물꼬트나? 북한, 상황 관리에 활용할 듯 판문점에서 무단...
# Processing label: 0
# Processing text: 尹대통령 “다음주 파리 국제박람회기구 BIE 총회 참석” 윤석열 대통령이 13일 서울 용산...
# Processing label: 3
# Processing text: "한국 먼저 설득해야" 133만톤 방류 앞둔 日 '총력 외교' 예고 국제원자력기구(IAEA...
# Processing label: 3
# Processing text: 尹지지율, 1.0%p 내린 38.1%…해외 순방에도 2주 연속 하락 [리얼미터] 윤석열 대...
# Processing label: 2
# Processing text: 민주당, 도감청 파문에 "용산 졸속 이전, 재집권시 다시 청와대 가야" 윤석열 대통령 취임...
# Processing label: 1
# Processing text: 野 ‘검사 탄핵’ 청원 5만명 넘어…개딸들 “이재명 나서라” 민주당이 지난 2월 17일 국...
# Processing label: 0
# Processing text: 국힘 "선관위, 권한쟁의심판 취하하고 감사원 감사 철저히 받아야"         노태악 선...
# Processing label: 0
# Processing text: 김동연 “고속도로는 양평 찾는 전국민 문제, 빨리 재개해야” 12일 김동연(왼쪽 사진) 경...
# Processing label: 4
# Processing text: 野 “尹장모 구속 일등공신”... 장제원 “저급한 아무 말 대잔치” 민주당 고민정 의원이 ...
# Processing label: 0
# Processing text: 태영호 "이재명, 러·중·북 군홧발에 짓밟히지 않으려면 정신 차리라" 태영호 국민의힘 최고...
# Processing label: 5
# Processing text: 북한, 현정은 방북 추진 일방적 거부…“아무도 못 들어와” 5일 오전 강원 고성군 제진역에...
# Processing label: 0
# Processing text: 잇따른 文청와대 출신 기소에…임종석 “정치 보복 아닌 스토킹” 임종석 전 청와대 비서실장은...
# Processing label: 0
# Processing text: 장관은 ‘욕먹는 책임’만, ‘실세는 차관’이 김대기 비서실장이 지난 29일 서울 용산 대통...
# Processing label: 2
# Processing text: 원전 오염수냐 처리수냐' 중국-일본 국제 무대에서 또 설전        일본 후쿠시마현 오...
# Processing label: 0
# Processing text: 양당제 폐해 벗어나려면, 연동형·권역별 비례대표제로 선거제도 바꿔야 2023년 4월 10일...
# Processing label: 0
# Processing text: 국힘 청년지방의원들 "학생인권조례 새로 제정하다시피 고쳐야"         한국교원단체총연...
# Processing label: 0
# Processing text: 김정숙 소환한 尹 '호위무사' 이용 "김건희 여사님은 굉장히 내조를 잘 하시는 분" 윤석열...
# Processing label: 0
# Processing text: 석방·석방·석방…이태원 참사 피고인 6명 모두 보석으로 풀려나 이태원 참사와 관련해 구속기...
# Processing label: 0
# Processing text: 중-러 '밀착' 계속… 가치 기반 '신냉전'도 심화        시진핑 중국 국가주석(왼쪽...
# Processing label: 0
# Processing text: 北, 블링컨 방중에 “압박 실패한 도발자의 수치스러운 구걸” 북한은 최근 토니 블링컨 미국...
# Processing label: 3
# Processing text: 국민의힘 거제시의원, 女주민 앞에서 손 갖다대며 "가진 건 두 쪽뿐" 국민의힘 소속 거제시...
# Processing label: 0
# Processing text: 유승민 "가장 두려운 건 '이재명 사퇴'…'윤석열 대 이재명' 구도 먼저 깨는 쪽이 이길 ...
# Processing label: 2
# Processing text: 김건희 모친·오빠·언니·동생 전수조사, 남양평IC 반경 5Km 안에 '축구장 5개' 땅 보...
# Processing label: 0
# Processing text: 인도, 한국·일본에 FTA 재협상 요구…"더 균형있고 공평해야"         피유시 고얄...
# Processing label: 0
# Processing text: 국힘의 ‘바닷물 먹방’ 소감…“짭조름한데” “의원님도 한입” 국민의힘 의원들이 30일 서울...
# Processing label: 2
# Processing text: 윤 대통령, 4박6일 프랑스·베트남 순방 마치고 귀국 프랑스·베트남 방문을 마친 윤석열 대...
# Processing label: 3
# Processing text: 美 동아태 차관보, 中방문 이틀 만에 방한 대니얼 크리튼브링크 미국 국무부 동아시아태평양 ...
# Processing label: 3
# Processing text: 입담 센 사람들 어디 갔나요…방송 與패널 유독 모자란 사연 내년 4·10 총선이 9개월 앞...
# Processing label: 0
# Processing text: 박진 “9회말 대역전극 마음으로 엑스포 유치” 박진 외교부 장관(맨 오른쪽)이 14일 오후...
# Processing label: 4
# Processing text: 민주당 "오염수 방류 동의, 수산물 수입금지와 양립 불가" 더불어민주당이 정부의 후쿠시마 ...
# Processing label: 0
# Processing text: 전세사기특별법 본회의 통과... 코인 신고 ‘김남국방지법’도 처리 여야는 25일 국회 본회...
# Processing label: 0
# Processing text: 박진, 26일부터 오스트리아·튀르키예·이탈리아 등 유럽 순방         박진 외교부 장...
# Processing label: 0
# Processing text: “나부터 먹겠다” 국민의힘, 오염수 괴담에 ‘횟집 회식’ 나섰다 오염수 방류 대응 관련 당...
# Processing label: 0
# Processing text: ‘수조물 드링킹’ 김영선…황당 지적에 “광어보다 펄떡 뛴다” 국민의힘 의원들이 지난 30일...
# Processing label: 2
# Processing text: 정부의 강제징용 배상금, 광주지법 직원이 공탁 거부 3일 오전 광주 동구 전일빌딩245에서...
# Processing label: 3
# Processing text: 김정은, 첫째 아들 없다? 통일연구원장 “딸 주애가 맏이일 가능성” 북한 김정은이 딸 김주...
# Processing label: 3
# Processing text: 홍준표, 하태경 두고 "간에 붙었다 쓸개 붙었다…얼마나 추하나" 홍준표 대구시장이 자신을 ...
# Processing label: 4
# Processing text: “백선엽 등 국가유공자 12명 명예회복 추진” 죽어서도 나라 지킨다… 백선엽 장군 동상 제...
# Processing label: 4
# Processing text: 민주화 유공자 기록 열람 거절에 與 “깜깜이 심사 하라는 말이냐” 국가보훈부가 더불어민주당...
# Processing label: 4
# Processing text: 野혁신위 “콩가루, 이중적” 김영주·송영길·이상민 때리면서... 李 얘긴 한마디도 안했다 ...
# Processing label: 0
# Processing text: 천화동인7호 실소유자' 피의자 신분 소환…1000만원 투자해 121억 받아        서...
# Processing label: 0
# Processing text: 尹대통령, 유럽 기업 6곳서 9억4000만달러 투자 유치 윤석열 대통령이 21일(현지시간)...
# Processing label: 4
# Processing text: 대통령실, 싱하이밍 中대사 겨냥 "가교 역할 부적절" 싱하이밍 주한 중국대사가 한국 정부의...
# Processing label: 4
# Processing text: 차수변경부터 증인채택 불발까지…'양평질의' 정쟁만 벌이다 종료        원희룡 국토교통...
# Processing label: 0
# Processing text: 北 황강댐 또 무단방류...우리측 요청 있었지만 무시해 북한 황강댐 방류에 대응하기 위해 ...
# Processing label: 0
# Processing text: 300억 들여 ‘선거 박물관’ 짓겠다는 선관위... 與 “퇴직자 일자리냐” 지난해 11월 ...
# Processing label: 2
# Processing text: 노회찬 5주기 추모전시회 "밤이 깊을수록 별은 더욱 빛납니다" 평등하고 공정한 나라 노회찬...
# Processing label: 0
# Processing text: "최악 상황 가정해 대응하라" 한총리, 오늘만 2차례 폭우 회의 한덕수 국무총리가 13일 ...
# Processing label: 3
# Processing text: 국힘 "이동관, 방송 정상화 첫걸음…논란은 청문회서 따져야"         이동관 방송통신...
# Processing label: 4
# Processing text: [속보] 고위당정, 철근 누락 사태에 "입주자 만족할 손해배상"         김정재 국민...
# Processing label: 0
# Processing text: “계엄군이 주인공” 野가 때린 보훈처 5‧18사진, 文정부도 썼다 보훈처가 18일 트위터에...
# Processing label: 4
# Processing text: 미 전략폭격기 ‘B-52H’ 한반도 상공 훈련 한·미 공군이 지난 3월6일 한반도 서해 상...
# Processing label: 0
# Processing text: 민주, 日오염수에 “유엔으로 가자”... 與 “국제적 망신” 임수석 외교부 대변인. /뉴스...
# Processing label: 0
# Processing text: 한덕수 “폭염특보 발효, 야외근로자 작업시간 조정” 긴급지시 한덕수 국무총리가 27일 정부...
# Processing label: 3
# Processing text: 野 싱크탱크 前부원장 “민주, 후쿠시마 대응 비과학적이고 선동적” 더불어민주당이 후쿠시마 ...
# Processing label: 2
# Processing text: 野송갑석 “이래경 임명은 인사 참사…최고위에 아는사람 한명도 없었던 듯” 송갑석 더불어민주...
# Processing label: 0
# Processing text: 마침내 '불체포특권 포기'한 민주당, 형식도 내용도 '어정쩡' 지적 더불어민주당이 불체포특...
# Processing label: 0
# Processing text: 국힘 윤리위, 홍준표 징계 수위 논의…"사과·수해봉사 종합적 판단"         황정근 ...
# Processing label: 0
# Processing text: [속보]"윤 대통령, 내달 2~8일 여름휴가…내수진작·지역경제 활성화"         윤석...
# Processing label: 3
# Processing text: 尹대통령 “교권 침해하는 불합리한 조례 개정 추진” 윤석열 대통령이 지난 18일 용산 대통...
# Processing label: 5
# Processing text: 73년 만에… 대한민국 지킨 영웅의 귀환 윤석열 대통령이 26일 오후 경기 성남 서울공항에...
# Processing label: 4
# Processing text: 윤 대통령, 정전 70주년 맞아 ‘파병국’ 룩셈부르크·뉴질랜드 정상 만나 윤석열 대통령이 ...
# Processing label: 3
# Processing text: 정부 "한일 국장급 회의서 오염수 모니터링 투명 진행 입장 강조"(종합)         박...
# Processing label: 4
# Processing text: 유인태 “조국 출마 안할 것...떨어지려고 무소속 나가겠나?” 조국 전 법무부 장관이 지난...
# Processing label: 0
# Processing text: [르포] 한·프랑스 전투기 편대, 佛참전용사 잠든 유엔공원 상공에         25일 우...
# Processing label: 3
# Processing text: 송영길 "어떤 일 당해도 도망가지 않아…내가 해결하겠다" 2021년 민주당 전당대회 당시 ...
# Processing label: 0
# Processing text: 영보자애원 찾은 김대남 비서관 “봉사시설 도울 방안 찾겠다”        김대남 대통령실 ...
# Processing label: 4
# Processing text: "건설이권 카르텔 발본색원" 윤재옥 기자간담회…국조 제안할 듯         윤재옥 국민의...
# Processing label: 0
# Processing text: "곳간 지킬게 아니라" 당 말렸던 '35조 추경안'…이재명 또 꺼냈다 이재명 민주당 대표가...
# Processing label: 4
# Processing text: 민주당, 이재명 직무정지 소송 낸 당원 징계 회부         더불어민주당 경기도당이 권...
# Processing label: 0
# Processing text: 대통령이 풍차 향해 달려가는 돈키호테가 되어가고 있다 "6·25 전쟁 당시 수많은 국가가 ...
# Processing label: 1
# Processing text: 尹지지율 38%…내년 총선 지지 與 46%, 野 41% [NBS] 윤석열 대통령. /뉴스1...
# Processing label: 3
# Processing text: 北 도발 응징할 ‘3天’ 모였다, 백령도에 대거 배치된 신무기들 서해 최북단 백령도 해병부...
# Processing label: 3
# Processing text: ‘출생통보제’ 법안 본회의 통과 30일 오후 국회 본회의에서 출생통보제 도입을 등을 위한 ...
# Processing label: 0
# Processing text: ‘이래경 사퇴’ 침묵하던 이재명 “결과에 무한책임 지는 게 당 대표 하는 일” 이재명 더불...
# Processing label: 0
# Processing text: 햄 2조각에 짜다 만 케첩…육군7군단, 코로나 격리장병에 부실급식 코로나19 격리 장병에게...
# Processing label: 2
# Processing text: “文정부, 사드 전자파 수십번 측정하고도 공개 안해” 경북 성주군 소재 주한미군 고고도미사...
# Processing label: 0
# Processing text: 외교·안보 정책도 수사로 뒤집는 윤석열 정부…대외신뢰는 무시 통일부는 2019년 11월 판...
# Processing label: 2
# Processing text: 학원 사업자, 국세청 세무조사로 6년간 세금 512억원 추가 납부 국세청이 최근 6년간 학...
# Processing label: 3
# Processing text: 돈봉투 사건에도… 거야 의원 또 ‘방탄 특권’ 이재명에 인사하는 윤관석 - 더불어민주당 전...
# Processing label: 0
# Processing text: 민주 “윤 대통령, 기시다 총리에 오염수 우려 분명히 전하라” 북대서양조약기구(NATO·나...
# Processing label: 2
# Processing text: 김건희 여사, 美매체와 인터뷰 ... “K컬쳐 영업사원 역할 할 것” 지난 4월 미국 국빈...
# Processing label: 4
# Processing text: 내년 총선 '野가 다수당 돼야' 49.8% vs. '與가 다수당 돼야' 37.4% 내년 4...
# Processing label: 0
# Processing text: [속보] 대통령실 "특별감찰관 임명, 여야 합의해서 와야"         용산 대통령실 청...
# Processing label: 3
# Processing text: 수해 골프' 홍준표, 8년 만에 또 징계 받나…與윤리위, 징계논의 착수 국민의힘 윤리위원회...
# Processing label: 3
# Processing text: 이재명 "尹 방미, 첫단추부터 잘못…한국은 美 속국 아냐" 돈봉투 살포 의혹으로 위기를 맞...
# Processing label: 1
# Processing text: 73년만에 돌아온 참전영웅 유해... 尹, 거수경례로 영접했다 윤석열 대통령이 26일 오후...
# Processing label: 3
# Processing text: ‘양평 대안 노선’ 용역사 증인채택 무산… 野 “그 회사는 국힘 대변인” 26일 서울 여의...
# Processing label: 0
# Processing text: 민주당, '정전 70주년 한반도 평화 구축 촉구 결의안' 발의 더불어민주당이 정전협정 70...
# Processing label: 2
# Processing text: 견학 초등생들 보고 있는데 막말 추태… 이럴거면 ‘19금 국회’로 국민의힘 김기현 대표가 ...
# Processing label: 0
# Processing text: 국힘, 김영호 통일부장관 청문회 조작영상 유포자 고발         김영호 통일부 장관이 ...
# Processing label: 3
# Processing text: 여야 수해복구 TF 첫 회의…"신속한 법안 처리" 한목소리          국민의힘 이양수...
# Processing label: 0
# Processing text: 野 "이동관 아들 학폭 피해자 최소 4명, 학폭은 무려 2년 동안 이뤄져" 방송통신위원장 ...
# Processing label: 2
# Processing text: ‘김건희 특혜 의혹’ 해명, “새빨간 거짓말 들통” [공덕포차] 서울-양평 고속도로 사업 ...
# Processing label: 1
# Processing text: “경찰은 수당 5배”… 해군 초급간부 730명, 해경 이직 열악한 처우 등으로 군을 떠나는...
# Processing label: 2
# Processing text: 윤 대통령 “한국·폴란드, 우크라 재건 최적의 파트너” 지난해 2월 러시아의 침공으로 발발...
# Processing label: 3
# Processing text: "장모 10원 한장" 尹 발언 재소환…野 "장모 불법 드러났는데 모르쇠냐" 더불어민주당이 ...
# Processing label: 3
# Processing text: 정부 "오송 참사 1~2시간 전 '긴급통제' 요청한 112 접수"…감찰 착수 지난 15일 ...
# Processing label: 3
# Processing text: 尹대통령, 이앙기 타고 모내기... 새참은 주민들과 잔치국수 윤석열 대통령이 7일 충남 부...
# Processing label: 3
# Processing text: 당정 “수해 재난지원금 대폭 인상…재난지역 추가 선포” 정부와 국민의힘은 28일 서울 삼청...
# Processing label: 5
# Processing text: 한 총리 "수소는 탄소 전환 핵심…기술 국산화 꼭 이뤄져야"(종합)         한덕수 ...
# Processing label: 4
# Processing text: 원희룡 "이해찬·이재명 지시로 거짓선동"…민주 "야당 대표가 친구냐"         원희룡...
# Processing label: 0
# Processing text: 국민의힘, 오늘 당무감사 공고…총선 대비 인적쇄신 착수         국민의힘. 2022....
# Processing label: 0
# Processing text: 정부 "오염수, 수산물 수입과 별개" vs 민주당 "기기묘묘한 주장" 더불어민주당이 후쿠시...
# Processing label: 2
# Processing text: 이주호 "학생인권 강조해 '교권' 추락" vs 조희연 "학생인권-교권, 충돌 안 해" 서울...
# Processing label: 3
# Processing text: 경찰, 대구시청 압수수색...홍준표 “수사권 갖자 뵈는 게 없나” 홍준표 대구시장이 지난 ...
# Processing label: 3
# Processing text: 방류 공방 속 과학자 만난 尹…“국제사회에서 제일 중요한 게 과학” 윤석열 대통령은 5일 ...
# Processing label: 3
# Processing text: 尹 "눈으로 보면 차이가 있다"…수해현장 연이틀 찾은 이유 “실행 가능한 겁니까. 현장에는...
# Processing label: 4
# Processing text: 소주 한잔 누구랑? 리허설 질문에 文 "조국인데 어찌하면 좋겠어?" 문재인 정부 청와대 국...
# Processing label: 0
# Processing text: 윤 “파리·베를린·런던도 위협”…북 무력시위에 국제공조 강조 북대서양조약기구(NATO·나토...
# Processing label: 3
# Processing text: “여권, 제정신 아니다”…재난 속 정치권 막말 퍼레이드 [공덕포차] 수십명의 인명 피해가 ...
# Processing label: 0
# Processing text: 윤재옥 “野, 김여사와 연관지어 악의적 선동...가짜뉴스 퍼뜨려” 국민의힘 윤재옥 원내대표...
# Processing label: 5
# Processing text: ”IAEA 규탄” 민주당 의총 및 규탄대회, 내일은 철야농성 더불어민주당이 5일 후쿠시마 ...
# Processing label: 2
# Processing text: 윤상현 "대통령 전면 나섰는데 中이 거부? 국가원수 체면이…" 윤석열 정부 대통령실과 여당...
# Processing label: 2
# Processing text: 중국 보란 듯… 한-베트남 “희토류 공급, 해양치안 협력 강화” 베트남을 국빈 방문한 윤석...
# Processing label: 3
# Processing text: 윤상현 "美정부·언론은 '문건유출 사실'이라는데 韓만 '위조'?" 미 정보기관의 대통령실 ...
# Processing label: 1
# Processing text: 수해방지' 도시침수법 제정·하천법 개정안, 환노위 전체회의 통과         박정 위원장...
# Processing label: 0
# Processing text: 돈봉투 피의자 송영길 “불체포 특권 포기는 야당이길 포기하는 것” 더불어민주당 송영길 전 ...
# Processing label: 0
# Processing text: 이부진의 요청… 김건희 여사, 한국방문의해 명예위원장 맡는다 윤석열 대통령 부인 김건희 여...
# Processing label: 0
# Processing text: 실업급여 개선' 野비판에…與 "불합리 개선해 공정한 제도 만들자는 것" 국민의힘 박대출 정...
# Processing label: 4
# Processing text: [오늘의 국회일정](1일, 화)         국회 본회의장. 뉴스1 © News1 송원영...
# Processing label: 0
# Processing text: 감사원, “방사청, 국산 무기 개조할 돈으로 외국 무기 업그레이드 지원” 국산 무기체계의 ...
# Processing label: 3
# Processing text: 인민이 목격한 3각 밀착… 김정은 '정상외교' 재개 [노동신문 사진]        (평양 ...
# Processing label: 0
# Processing text: 국민의힘 김성태 "69시간 안돼…52시간제 존중해야" 한국노총 출신인 김성태 국민의힘 중앙...
# Processing label: 2
# Processing text: "권영준, 18억 고액보수 받고 가진 자 대변…대법관으로 부적절" 권영준 신임 대법관 후보...
# Processing label: 0
# Processing text: 정치공방에 사라진 재난 주무장관...행안부 “차관 대행으론 한계 느껴” 직무정지 상태인 이...
# Processing label: 5
# Processing text: [속보] '민주 돈봉투' 송영길 후원조직 관련 前여수상공회의소장 압수수색          ...
# Processing label: 0
# Processing text: 박대출 “노무현 정부도”…풍수학자 ‘비공개 답사’ 감싸기 박대출 국민의힘 정책위의장이 지난...
# Processing label: 1
# Processing text: 감사원 “전현희, 아들 軍 특혜 의혹 추미애에 유리한 유권해석” 전현희 국민권익위원장이 감...
# Processing label: 3
# Processing text: 여야 청년정치인 "'비례 확대' 등 공론조사 결과, 국회 표결에 부쳐야" 여야 청년 정치인...
# Processing label: 0
# Processing text: 북한, 서해상으로 ‘핵탄두 탑재 가능’ 순항미사일 여러 발 발사 지난 2021년 9월13일...
# Processing label: 0
# Processing text: [단독] "4대강 찬성자 위원회 빼라" 文정부 시민단체 위력 컸다 문재인 정부 기간 금강·...
# Processing label: 0
# Processing text: 김어준 "교사 극단선택, 與의원 연루" 주장…국힘, 고발할 것 국민의힘이 최근 초등학교 교...
# Processing label: 0
# Processing text: 오늘부터 TV수신료·전기요금 따로 낼 수 있다 TV 수신료(KBS·EBS)를 전기요금과 분...
# Processing label: 3
# Processing text: 윤 대통령 "수해 복구, 종전보다 기준 높여 충분히 지원"(종합)         윤석열 대...
# Processing label: 3
# Processing text: 宋, '돈봉투' 알았나? 이정근 "송영길이 '강래구 돈 많이 썼냐' 묻더라" 더불어민주당의...
# Processing label: 0
# Processing text: 해군, 한·미·일·호 연합해상훈련 ‘퍼시픽 뱅가드' 참가 25일 해군의 4400톤 구축함 ...
# Processing label: 0
# Processing text: 여야 5명씩 모인다…'수해 대책 TF' 구성 합의, 26일 첫 회의 여야가 집중호우로 인한...
# Processing label: 4
# Processing text: 윤 대통령-젤렌스키, 키이우서 2시간 정상회담 우크라이나를 전격 방문한 윤석열 대통령이 1...
# Processing label: 3
# Processing text: 안철수, ‘김은혜 출마설’에 “정부에서 해야할 역할 많을 수도” 2022년 5월 27일 당...
# Processing label: 0
# Processing text: 檢, 박영수 구속영장 재청구…딸이 받은 '11억' 혐의 추가(종합)         이른바 ...
# Processing label: 0
# Processing text: 마타렐라 伊대통령 "'담대한 구상' 통찰력 있어… 北 수용하기 바라"         박진 ...
# Processing label: 0
# Processing text: 尹, 베트남전·대간첩 작전 전사자 묘역 깜짝 방문... 유족 “살다 보니 이런 날이” 윤석...
# Processing label: 3
# Processing text: “불체포특권 먼저 포기하겠다”…비이재명계 31명 입장 발표 이재명 더불어민주당 대표가 14...
# Processing label: 0
# Processing text: 국토위 시작부터 충돌…여 "전례없는 공개" 야 "원희룡 사과하라"         원희룡 국...
# Processing label: 4
# Processing text: 미 핵추진잠수함 제주 입항…켄터키함 간 지 사흘 만에 미국의 엘에이(LA)급 핵추진잠수함(...
# Processing label: 0
# Processing text: 정부 “오염수 검증 중… 국제 기준 충족 못하면 방류 반대할 것” 일본 도쿄전력이 후쿠시마...
# Processing label: 4
# Processing text: 이승만 바로보기 운동 원로들 “잃어버린 나라 되찾은 기분” 2022년 7월 19일 서울 동...
# Processing label: 4
# Processing text: 출범 한 달 김은경 혁신위, '혁신' 대신 '설화'만? 출범 한 달을 맞은 더불어민주당 '...
# Processing label: 0
# Processing text: 실시간 네이버 화면 복제한 北의 ‘해킹 사이트’... 접속땐 개인정보 털린다 정상 네이버 ...
# Processing label: 0
# Processing text: 경찰·소방 승진임용 전 순직시 사망 전날 승진' 개정안, 만장일치 통과         김진...
# Processing label: 0
# Processing text: 새 통일연구원장에 김천식 전 차관 김천식 새 통일연구원장. 사진 통일연구원 제공    국무...
# Processing label: 3
# Processing text: 73년만에 유해로 상봉한 ‘6·25 호국 형제’...尹대통령, 안장식 엄수 제68회 현충일...
# Processing label: 3
# Processing text: 美국무부, '北, 대러 무기 제공 가능성'에 "주저없이 제재할 것"         매슈 밀...
# Processing label: 0
# Processing text: 막말 논란에 또 막말 대응… 野대변인, 천안함장에 “부하 죽이고 무슨 낯짝으로” 최원일, ...
# Processing label: 0
# Processing text: “가죽 벗기고 뼈 깎겠다”지만… 민주당 혁신위에 친명계가 5명 더불어민주당 김은경 혁신위원...
# Processing label: 0
# Processing text: "김건희 에코백 속 샤넬백"이라더니…가짜뉴스 실토한 민주당 더불어민주당 박영훈 청년미래연석...
# Processing label: 0
# Processing text: 尹 “우크라 재건 협력... 지뢰제거장비·긴급후송車 신속 지원” G7 정상회의 참관국 자격...
# Processing label: 4
# Processing text: 오염수 밤샘농성 민주당 “정부 발표,  IAEA 받아쓰기…일본 대변” 이재명 더불어민주당 ...
# Processing label: 1
# Processing text: 한동훈 “이재명, 말이 길다” 민형배 “너나 짧게 하시길” 한동훈 법무부 장관이 26일 오...
# Processing label: 3
# Processing text: 유인태 "내가 듣기론 연말쯤 이재명 대신 비대위, 친명 비명 공감대…"         이재...
# Processing label: 0
# Processing text: 오코노미야끼 나눠 먹었다... 김건희·기시다 여사, 별도 오찬 일본을 방문 중인 윤석열 대...
# Processing label: 3
# Processing text: 평화의 길을 찾아 나선 미래의 주역들 중앙일보와 (재)한반도평화만들기(이사장 홍석현 중앙홀...
# Processing label: 0
# Processing text: "양평고속道 원안 종점 일대 1만m²...그땅 주인은 민주 前군수" 박대출 국민의힘 정책위...
# Processing label: 3
# Processing text: 여야, 후쿠시마 검증 특위·선관위 국정조사 합의 여야가 8일 후쿠시마 원전 오염수 관련 검...
# Processing label: 0
# Processing text: 법사위 '검찰특활비' 과방위 '전체회의 소집'…여야, 상임위 곳곳 충돌         김도...
# Processing label: 0
# Processing text: 감사원 1차장에 최달영… ‘적극 행정 면책’ 설계자 최달영 감사원 제1차장. /감사원 제공...
# Processing label: 3
# Processing text: “천공이 아니라서 말 안 했다”?...“풍수가면 문제가 달라지나?” [시종땡] 지난해 대통...
# Processing label: 0
# Processing text: 외신기자 "5명 사망, 이재명은 위험 인물?"…李 "그들 사망에 어떤 영향도 못 미쳐" 이...
# Processing label: 1
# Processing text: 김남국, '60억 가상화폐' 논란에 "한동훈 검찰 작품"…한동훈 "적발돼라 한적 없어" 6...
# Processing label: 4
# Processing text: 성주 농가 “괴담은 우릴 죽이는 폭력”... 與, 참외 먹방하고 400박스 샀다 국민의힘 ...
# Processing label: 0
# Processing text: 법무부 직원들 공개했는데...野 박찬대 “한동훈이 공직자 코인 신고 반대” 박찬대 더불어민...
# Processing label: 2
# Processing text: 양향자 신당 ‘한국의 희망’ 출범… “새 시대로 건너가자” 양향자 한국의희망 창당준비위원장...
# Processing label: 0
# Processing text: 여야 오늘 수해복구·피해지원TF 회의… 8월 중 법안 처리에 속도        국민의힘 이...
# Processing label: 0
# Processing text: 부사관 지원율도 역대 최저… 작년 선발 인원 1900명 못 채워 이종섭 국방부 장관이 지난...
# Processing label: 3
# Processing text: 軍, 北발사체 잔해 또 찾았다...정찰위성 ‘만리경 1호’ 가능성 북한이 탄도미사일 기술을...
# Processing label: 3
# Processing text: 北은 반격 훈련에 반발, 동해로 탄도미사일 2발 발사 북한 탄도미사일 . /평양 노동신문 ...
# Processing label: 0
# Processing text: 이재명 "日, 후쿠시마 오염수 마실 수 있다? 식수로 사용하라" 이재명 더불어민주당 대표가...
# Processing label: 1
# Processing text: [단독] IAEA 사무총장, 野 의혹제기에…"집권해도 IAEA 상대 안할건가" 라파엘 그로...
# Processing label: 0
# Processing text: [단독] 민주당 ‘직장 내 괴롭힘’ 징계 대폭 감경 논란 더불어민주당 이재명 대표가 26일...
# Processing label: 0
# Processing text: 尹대통령, 베트남 호찌민 묘소 찾아 참배 윤석열 대통령과 김건희 여사가 23일(현지 시각)...
# Processing label: 3
# Processing text: 與 "네이버 뉴스 조작" 의혹 제기…尹지지율 '뚝뚝' 떨어지는 건 '언론탓'? 국민의힘이 ...
# Processing label: 4
# Processing text: 외교부, 北 전승절 행사에 "주민 생활고 외면… 핵위협 규탄"         임수석 외교부...
# Processing label: 0
# Processing text: 민주당 "김건희 여사 '리투아 명품 쇼핑' 보도 해명하라" 더불어민주당이 14일 “김건희 ...
# Processing label: 0
# Processing text: [단독] 원희룡, 화물연대 ‘동향 파악’ 공무원 70명에 표창 원희룡 국토교통부 장관이 1...
# Processing label: 2
# Processing text: 윤 대통령이 中과 '당당히' 싸우는 사이 중국에 손 내미는 美와 英 지난 5월 일본 히로시...
# Processing label: 2
# Processing text: 홍준표 "대구경찰과 퀴어단체는 '공범'…고발하겠다" 대구 퀴어축제 관계자들이 홍준표 대구시...
# Processing label: 4
# Processing text: 원희룡 '고양갑' 출마? 심상정 "어금니 꽉 깨무시라. 많이 아프다"" 심상정 정의당 의원...
# Processing label: 1
# Processing text: 윤 대통령, 주러대사에 이도훈 전 외교부 2차관 임명 이도운 전 외교부 2차관. 대통령실 ...
# Processing label: 3
# Processing text: "'친중' 文때 얻은 게 뭔가" 하루 두번 中 때린 尹, 경제보복 현실화? 윤석열 대통령이...
# Processing label: 2
# Processing text: 윤 대통령 지지율, 2%p 오른 35%…국민의힘 35%·민주당 29%         윤석열...
# Processing label: 5
# Processing text: 美 핵전력 운용 때 '한국 발언권 제도화' 첫발…파트너 인정 18일 서울에서 열린 한·미 ...
# Processing label: 4
# Processing text: 尹대통령 “정치 파업·불법 시위에 절대 굴복 안해” 윤석열 대통령이 4일 오전 청와대 영빈...
# Processing label: 5
# Processing text: 檢스플레인과 '차관 통치', 尹에 드리워진 MB 그림자 △MB는 정치 입문 전 다양한 경험...
# Processing label: 2
# Processing text: 민주, 우여곡절 끝 혁신위원장에 김은경 발표 더불어민주당이 '이래경 낙마' 사태 열흘 만에...
# Processing label: 0
# Processing text: 김영주 “본회의 중 사적문자 죄송”...내로남불 해명은 없었다 뉴데일리가 30일 포착한 김...
# Processing label: 0
# Processing text: 이재명 "간호법은 尹 공약"…거부권 행사 압박 여야가 국회에서 이뤄진 '쌍특검('50억 클...
# Processing label: 1
# Processing text: 북한, 코로나 이후 첫 외빈 초청…中대표단 전승절 경축행사 참가 북한이 오는 27일 ‘전승...
# Processing label: 2
# Processing text: 윤영찬 “尹, 사실상 쿠데타로 대통령 됐다” 윤영찬 더불어민주당 의원./뉴스1  더불어민주...
# Processing label: 1
# Processing text: 尹대통령, 비서관 출신 차관들에 "이권 카르텔과 싸우라" 윤석열 대통령은 29일 정부부처 ...
# Processing label: 4
# Processing text: [단독] "이승만 재평가" 뜻모은 尹 남자들…한동훈은 '홍보' 조언 “이승만 전 대통령에 ...
# Processing label: 4
# Processing text: [단독] 최재해, 감사위원들 조사 지시…사실상 조은석 표적감찰 논란 서울 삼청동 감사원. ...
# Processing label: 2
# Processing text: "반국가세력" 발언으로 지지층 결집? 尹대통령 지지율 40%대 재진입 윤석열 대통령의 지지...
# Processing label: 3
# Processing text: 아들 학폭' 의혹 이동관 "무책임한 폭로와 가짜뉴스" 신임 방송통신위원장 지명이 유력한 것...
# Processing label: 4
# Processing text: 文의 종전선언·평화협정 삭제... 尹정부 새 안보전략 나왔다 윤석열 대통령이 7일 충북 청...
# Processing label: 4
# Processing text: 해병대 “실종자 수색 중 숨진 해병 유족께 사과…경위 조사 중” 경북 예천 내성천에서 급류...
# Processing label: 3
# Processing text: 尹대통령, 자갈치 방문해 '괴담' 운운하자 민주당 "왜 수산물 소비 꺼리겠나" 윤석열 대통...
# Processing label: 1
# Processing text: [단독] 군사학회 특강하는 김성한… 사실상 안보특보로 활동 재개 김성한 전 국가안보실장. ...
# Processing label: 3
# Processing text: 尹대통령, '文정부 태양광 비리' 겨냥 "철저 조사하라" 감사원이 문재인 정부 시기에 진행...
# Processing label: 4
# Processing text: 이재명 “日 오염수 안전하면 식수로” 與 “깨끗하다고 화장실 물 먹나” 더불어민주당 이재명...
# Processing label: 0
# Processing text: 당정 "규제 위주 어업정책, 국제기준 맞춰 선진화해야"           박대출 국민의힘 ...
# Processing label: 3
# Processing text: MBC 경영관리' 소홀했나…감사원 10일부터 방문진 현장감사 감사원은 오는 10일부터 방송...
# Processing label: 3
# Processing text: 홍준표 "대구경찰 이제 막가는구나, 깡패냐?…그래 끝까지 가보자" 경찰이 홍준표 대구시장의...
# Processing label: 5
# Processing text: 김여정, 美·유엔 싸잡아 비난…"우리 건드린 대가 가볍지 않아" 김여정 북한 노동당 부부장...
# Processing label: 0
# Processing text: 윤 대통령 “반국가세력이 종전선언 노래”…야 “극우적 인식 충격” 윤석열 대통령이 28일 ...
# Processing label: 1
# Processing text: 정세현 "북일 물밑접촉 하는 듯…뒤통수 안 맞으려면 대북 정책 변화해야" 남북 간 첫 정상...
# Processing label: 0
# Processing text: 조원진 "홍준표 '나 빼고 다 하이에나'…추가징계 겁나 글 지워놓곤 사자?"        ...
# Processing label: 1
# Processing text: 샘플 조사 23명 중 생존 확인된 아기는 1명뿐 감사원이 각 지방자치단체에 생사를 확인해 ...
# Processing label: 3
# Processing text: 이재명-이낙연 11일 '명낙 회동'…화합이냐 파국이냐 이재명 더불어민주당 대표와 이낙연 전...
# Processing label: 0
# Processing text: 국군 전사자 유해, 軍수송기로 하와이 출발… 오후 서울공항 도착(종합)  미국에 있던 한국...
# Processing label: 0
# Processing text: 유엔사 “월북 미군 관련 북과 대화 시작”…핑크폰 통화한 듯 유엔군사령부는 24일 판문점을...
# Processing label: 4
# Processing text: 북한·중국 부러웠나? 광화문서 '軍시가행진'…업체에 개발 중 무기+비용 내라? 국군의 날 ...
# Processing label: 2
# Processing text: 수해 순직 고 채수근 상병 영결식…유족 “원인규명·근본대책 마련을” 고 채수근 상병의 안장...
# Processing label: 3
# Processing text: “달콤한 시럽급여 안 된다”…당정, 실업급여 하한액 하향·폐지 검토 정부·여당이 최저임금의...
# Processing label: 3
# Processing text: 올리버 스톤, ‘판도라’ 직격 “비과학적 영화가 원전공포 조장” 올리버 스톤 감독  “환경...
# Processing label: 0
# Processing text: 폭행 혐의로 구금됐던 미국 현역 군인, JSA 통해 무단 월북 판문점 공동경비구역(JSA)...
# Processing label: 0
# Processing text: 중·러 보란듯...美 핵항모, 호크아이·스텔스기 띄워 훈련 미 해군 정찰기 호크아이가 니미...
# Processing label: 3
# Processing text: 국민의힘 윤리위, 김재원·태영호 징계 절차 착수 국민의힘 중앙당 윤리위원회가 김재원, 태영...
# Processing label: 0
# Processing text: 대구시 공공기관장 인사청문회 '조례' 제정…"인사행정 공정성 확보"         대구시의...
# Processing label: 3
# Processing text: 尹대통령 취임 1년, 여론의 평가는? 윤석열 대통령 취임 1주년을 맞아 각 언론사들이 시행...
# Processing label: 2
# Processing text: 이재명, 일 총리에 서한…"후쿠시마 오염수 방류 보류해달라"         이재명 더불어민...
# Processing label: 0
# Processing text: 배꼽티 입은 류호정, 탈코르셋 지적에 "멋있게 입고 싶었을 뿐" 류호정 정의당 의원은 ‘서...
# Processing label: 0
# Processing text: 순방 마친 尹대통령 “장마철 인명피해 예방 철저히 대비하라” 프랑스와 베트남 순방을 마친 ...
# Processing label: 3
# Processing text: 김기현 "호남서 '볼매' 인정받겠다…지역구보다 더 많이 찾아"         김기현 국민의...
# Processing label: 0
# Processing text: 野 "국산 수산물만 회식"에…장제원 "한심하다, 日대변인이냐" 국회 과학기술정보방송통신위원...
# Processing label: 0
# Processing text: 김선교 "원희룡 '고속도로 백지화' 아주 소신 있게 잘했다" 국민의힘 소속 여주·양평 당협...
# Processing label: 3
# Processing text: [단독] “징용 판결금 중 5126만원 달라” 지원단체, 내용증명 보냈다 정부가 일제강점기...
# Processing label: 1
# Processing text: 野 4당 "이상민 파면, 공직사회 경종"…헌재에 최종의견서 제출 더불어민주당 등 야(野) ...
# Processing label: 2
# Processing text: 초조함 드러낸 김여정 협박…그뒤엔 나토·아세안 손잡는 한국 대륙간탄도미사일(ICBM) 발사...
# Processing label: 3
# Processing text: 김은경, '노인 폄훼' 나흘 만에 사과…당 내외 사퇴 요구(종합)         김호일 대...
# Processing label: 0
# Processing text: 野 “IAEA 보고서 공정하지 않을 것” 與 “궁예 관심법인가” 더불어민주당 이재명(오른쪽...
# Processing label: 0
# Processing text: 이원욱 "민주당, '개딸'의 '수박 깨기' 대상 돼…부끄럽다" 더불어민주당 '비(非)이재명...
# Processing label: 0
# Processing text: 황보승희 탈당, 총선 불출마 국민의힘 황보승희(부산 중·영도) 의원이 19일 탈당을 선언하...
# Processing label: 0
# Processing text: 월북 미군 母 "자랑스러운 아들, 그럴 리 없다…집 돌아오길" 판문점 공동경비구역(JSA)...
# Processing label: 0
# Processing text: [속보]'수해방지' 도시침수법 제정·하천법 개정안 환노위 소위 통과             ...
# Processing label: 0
# Processing text: 남조선' 대신 '대한민국' 강조했다…김여정 갑자기 말바꾼 이유 북한 김여정 노동당 부부장이...
# Processing label: 0
# Processing text: 尹 “너무 늦어 죄송” 원폭 피해자 “꿈꾸는 듯 감격” 윤석열 대통령이 19일 7국(G7)...
# Processing label: 5
# Processing text: 강제동원 피해자 권리 없애려던 윤석열 정부, 법원에 제동 걸려 정부가 일제강점기 강제동원 ...
# Processing label: 1
# Processing text: 일본에 "성의있는 호응" 기대한다던 정부, 되레 연일 '독도는 일본땅'만 이어져 일본이 독...
# Processing label: 1
# Processing text: 김은경 혁신위 '혁신'은 대의원제 폐지?…설문조사 17문항 중 9개 배분        김은...
# Processing label: 0
# Processing text: 홍준표도 안철수도 '원팀' 목소리…국힘, 이준석·유승민도 끌어당길까         이준석 ...
# Processing label: 0
# Processing text: "일본이 선정한 차세대 지도자, 김태효 국가안보실 제1차장" 누구를 위한 '관계 개선'인가...
# Processing label: 1
# Processing text: 대통령실 "한일관계 주도권 쥔 측면 있다" 자평 윤석열 대통령은 "한일 정상회담에서 논의된...
# Processing label: 5
# Processing text: “노회찬 있었다면 단일화” 송영길 발언에... 정의당 “고인 모독” 반발 전당대회 돈봉투'...
# Processing label: 0
# Processing text: 의혹 꺼낸 이해찬에 與 “세종 연기 나들목 특혜 의혹의 당사자” 이해찬 더불어민주당 상임고...
# Processing label: 4
# Processing text: 김여정, 남조선 대신 ‘대한민국’ 첫 표현…“사실상 도발 예고” 김여정 북한 노동당 부부장...
# Processing label: 3
# Processing text: [단독] 감사원, 김은경 수사의뢰…"4대강 보해체 부적절 개입" 감사원이 문재인 정부의 4...
# Processing label: 3
# Processing text: “한강의 기적이 드니프로강의 기적으로” 아시안리더십콘퍼런스(ALC)에 참석하기 위해 방한한...
# Processing label: 4
# Processing text: “김정은에 北인권 따져라” 했던 김영호, 통일부 바꾼다 윤석열 대통령이 29일 김영호 통일...
# Processing label: 4
# Processing text: 국민의힘 "野, 거부권으로 '대통령 일방독주' 프레임 씌우려" 국민의힘 유상범 수석대변인이...
# Processing label: 5
# Processing text: “정치복원 위해 여야는 대화, 대통령은 국회 존중을” 11인 원로회 발족 양극단으로 치닫는...
# Processing label: 0
# Processing text: 기르던 ‘새’의 털 뽑아 아버지 베개 만든 김정일 ... 北 소학교 교재에 등장 김정일이 ...
# Processing label: 0
# Processing text: 정부 “IAEA 검증결과 존중...우리측 검토도 끝나는대로 발표” 정부는 5일 일본 후쿠시...
# Processing label: 4
# Processing text: 영아 살해·유기, 일반 살인·유기죄 적용…처벌 강화 출생신고도 안 된 ‘그림자 아기’들이 ...
# Processing label: 0
# Processing text: 尹대통령 "한국은 유엔군 피묻은 군복 위에 서 있어" 윤석열 대통령은 27일 "오늘의 대한...
# Processing label: 5
# Processing text: 中, 민주당 방중단에 “한중 관계 악화는 미국 때문” 중국을 방문한 더불어민주당 홍기원(왼...
# Processing label: 1
# Processing text: 합참, 북한위성 잔해물 인양·탐색 …“군사적 효용성 없다” 군 당국이 북한 ‘우주발사체’ ...
# Processing label: 3
# Processing text: 윤영찬 "'엄중낙연'이 변했다…'귀국 일성'에 저희도 굉장히 놀라" 이낙연 더불어민주당 전...
# Processing label: 0
# Processing text: 사형 선고 30년 지나도 집행 가능하도록…개정법 국회 통과 사형 선고 이후 30년이 지나면...
# Processing label: 0
# Processing text: 고민정 "尹장모 구속 부메랑 됐다"…장제원 "아무 말 대잔치" 장제원 국민의힘 의원은 24...
# Processing label: 3
# Processing text: [속보] 고위당정 "특별재난지역 추가 선포…기후위기 범정부 TF 구성"         김대...
# Processing label: 4
# Processing text: 유엔사 "미국인, 공동경비구역 견학 중 무단 월북" 유엔군사령부는 “공동경비구역을 견학하던...
# Processing label: 3
# Processing text: 이준석 "여성부 폐지 '7글자', 나와 상의 없었다" 안티-페미니즘(反여성주의) 정치의 기...
# Processing label: 0
# Processing text: 양평고속道 '김건희 일가 특혜 의심' 60.9% vs. '특혜와 무관' 32.1% 서울-양...
# Processing label: 1
# Processing text: ‘윤심 개각’을 바라보는 정치만렙 윤여준의 일침 [시사종이 땡땡땡] <한겨레> 새 시사프로...
# Processing label: 1
# Processing text: 김재원 '당원권 정지 1년', 태영호는 '3개월', 솜방망이? 국민의힘이 김재원 최고위원에...
# Processing label: 0
# Processing text: 국힘, 권영세 등 의원 코인 공개한 윤리심사자문위 고발키로 국민의힘 윤재옥 원내대표가 25...
# Processing label: 0
# Processing text: ‘타다법’ 냈던 박홍근, 당내외 비판에 “윤석열 검찰 기소 탓” 박홍근 더불어민주당 의원....
# Processing label: 1
# Processing text: 조국 출마하면 땡큐' 국민의힘…장예찬 "제발로 조국의 강 대환영" 조국 전 법무부장관의 총...
# Processing label: 0
# Processing text: 일반 유권자들도 선거운동 어깨띠 착용 가능해진다 지난 6월20일 오전 국회에서 열린 정치개...
# Processing label: 0
# Processing text: 野 "尹대통령은 배경, 김건희 여사가 중심…대한민국 대통령이 몇명인가?" 고민정 더불어민주...
# Processing label: 0
# Processing text: 북한 참여 ARF, '북한 비핵화' 아닌 '한반도 비핵화' 강조 북한이 참여하는 다자회의인...
# Processing label: 0
# Processing text: 민주 "검찰, 김성태 주가조작도 봐주기 기소…직무유기·직권남용"         해외 도피생...
# Processing label: 0
# Processing text: 한동훈 “소리지르지 마” 박범계 “가볍기가 깃털”…‘최은순 구속’ 설전 한동훈 법무부 장관...
# Processing label: 2
# Processing text: 중국, 민주당 방중단에 “한중관계 악화, 美때문… 한국, 선의의 조치 해야” 중국을 방문한...
# Processing label: 2
# Processing text: 한·UAE "원자력 에너지 평화적 이용 등 협력 강화·확대"          제5차 한·U...
# Processing label: 3
# Processing text: 국회의원 10명 중 3명은 ‘전과자’…경실련 “공천개혁 필요” 21대 국회의원 94명은 범...
# Processing label: 0
# Processing text: 文 만난 조국 “文정부 모든 게 부정당해...뭘 할지 고민 중” 조국 전 법무부 장관이 1...
# Processing label: 0
# Processing text: 장제원 "우주항공청법 통과시켜주면 사퇴"…과방위 무슨 일 국민의힘 소속인 장제원 국회 과학...
# Processing label: 0
# Processing text: 원희룡 “서울~양평 고속도로 사업 백지화... 야당은 소설 그만쓰라” 원희룡 국토교통부 장...
# Processing label: 4
# Processing text: 암살드론·스텔스기도 띄웠다… 韓美, 역대최대 ‘對北 반격훈련’ 2023년 6월 7일 진행된...
# Processing label: 4
# Processing text: 내달 18일 미 대통령 별장 캠프 데이비드에서 한ㆍ미ㆍ일 정상회담 연다 윤석열 대통령이 조...
# Processing label: 4
# Processing text: 문재인, 윤 정부 겨냥 "5년 성취 순식간에 무너져 허망" 문재인 전 대통령이 자신을 소재...
# Processing label: 1
# Processing text: 민주당, 김홍걸 복당 최종 의결…“보조금 유용 정황 없어” 김홍걸 무소속 의원. 연합뉴스 ...
# Processing label: 0
# Processing text: 이진복 '태영호 녹취록' 논란에 "공천 얘기 나눈 적 없다" 대통령실 이진복 정무수석은 국...
# Processing label: 0
# Processing text: 유승민 "대통령·당 망하는 길로 가고 있어…대구에 우병우·유영하 등판론이라니" 국민의힘 유...
# Processing label: 1
# Processing text: 이원욱 "野, 김남국 제명해야…도덕성 논란 선 그어야 총선 치러" 이원욱 더불어민주당 의원...
# Processing label: 0
# Processing text: [단독] 자통 하부망인 일명 ‘이사회’…전교조 강원지부 등 압수수색 국가정보원이 2022년...
# Processing label: 3
# Processing text: 오늘 이동관 방통위원장 지명...김영호 통일장관 임명안 재가 윤석열 대통령이 28일 신임 ...
# Processing label: 3
# Processing text: 안철수 "尹 정부도 '내로남불' 그대로…이대로면 총선 어렵다" 국민의힘 차기 대선주자 중 ...
# Processing label: 2
# Processing text: 김영호 후보자 "박근혜, 탄핵당할 만큼 잘못한 것 없어" 2017년 박근혜 대통령 탄핵에 ...
# Processing label: 4
# Processing text: 공천룰·기명투표' 놓고 깊어지는 '친명-비명' 계파 갈등        이재명 더불어민주당 ...
# Processing label: 0
# Processing text: 민주당·한동훈 ‘이화영 접견 시도’ 놓고 충돌 26일 국회 법제사법위원회 전체 회의에 출석...
# Processing label: 3
# Processing text: “여론조사 신뢰성 평가해 A·B·C 등급 매기자” 중앙선거여론조사심의위원회(여심위)와 여야...
# Processing label: 3
# Processing text: 尹대통령 "중국대사, 2인자라도 되는 줄 알고 못 만나서 안달 났나" 윤석열 대통령이 싱하...
# Processing label: 4
# Processing text: 국힘, 총선 다가오자 또 ‘포털 뉴스’ 때리기…KBS2 폐지도 요구 박성중 간사 등 국민의...
# Processing label: 2
# Processing text: [단독] 前 하동·함양군수와 함평군수… 감사원, 직권남용 등 비위 적발 감사원이 전·현직 ...
# Processing label: 3
# Processing text: 북한, 미국의 집속탄 제공에 "반인륜적 만행" 비판 최선희 북한 외무상이 우크라이나에 대한...
# Processing label: 0
# Processing text: 보훈부, 순직 고 채수근 상병 대전현충원에 안장키로 21일 경북 포항 해병대 1사단에 마련...
# Processing label: 3
# Processing text: 진중권, '김건희 명품' 논란 두고 "호객행위로 방문? 남대문도 아니고 누가…" 진중권 광...
# Processing label: 2
# Processing text: 세금으로 지인 땅 보상… 보성·강진군 공무원 비리 무더기 적발 감사원이 지난 19년간 감사...
# Processing label: 3
# Processing text: 박광온 “수해복구·피해지원 여야정 TF 구성” 제안 박광온 더불어민주당 원내대표가 18일 ...
# Processing label: 0
# Processing text: 안철수 "尹 우크라 방문 맞지만…수해 수습뒤 가는 걸로 했어야" 안철수 국민의힘 의원은 윤...
# Processing label: 1
# Processing text: 워싱턴선언 '동상이몽'? 대통령실 "사실상 핵공유" 美당국자 "핵공유 아냐" 윤석열 대통령...
# Processing label: 2
# Processing text: 민주당 혁신위원에 '친문' 황희 추가발탁…'이재명 혁신위' 오명 벗을까 더불어민주당 쇄신 ...
# Processing label: 0
# Processing text: 윤 대통령, 유엔군 참전용사 '최고 영접'…정전 70주년 기념식 참석         윤석열...
# Processing label: 3
# Processing text: 대통령실발 ‘실세 차관’ 부처 전진 배치…전문성은 ‘묻지마’ 윤석열 대통령이 28일 청와대...
# Processing label: 3
# Processing text: 日 "韓 전문가 상주, 구체적 협의 중…방류 데이터 실시간 공개" 국제원자력기구(IAEA)...
# Processing label: 4
# Processing text: 홍준표, 이재명 만나 "우리 당 대표는 옹졸해서…" 국민의힘 원로이자 차기 대선주자 중 하...
# Processing label: 2
# Processing text: 박지원 "바보 대통령실? 尹이 한소절 더 안했으면 바이든이 '듀엣'하려 했다는데" 박지원 ...
# Processing label: 1
# Processing text: 이준석 "풍수는 쉴드치면서 오염수는 '과학'으로? 이게 맞나" 지난해 대통령 관저 선정 과...
# Processing label: 0
# Processing text: “대동강변 산보하며 맥주” ‘송아·유미’ 채널 폐쇄에도 살아남은 北 유튜브 구글이 최근 유...
# Processing label: 0
# Processing text: 감사원 "환경부, 4대강 보 해체 졸속 결정"…김은경 수사요청 문재인 정부 시절 금강·영산...
# Processing label: 3
# Processing text: ‘후쿠시마 시찰단’ 21명, 21~26일 방일… “오염수 정화 직접 확인” 유국회 전문가 ...
# Processing label: 4
# Processing text: 수변공원 자리 독점 '알박기 텐트·캠핑카' 단속 강화되나        김승남 의원     ...
# Processing label: 0
# Processing text: 안보실, 휴가철 앞두고 철도 교통망 사이버 대응태세 점검 임종득 국가안보실 2차장은 5일 ...
# Processing label: 3
# Processing text: 고위당정, 철근 누락 사태에 "계약해지권 부여·국조 추진"(상보)         한덕수 국...
# Processing label: 0
# Processing text: 수신료 분리징수 시행령 개정에… 野, 무력화 법안 발의 더불어민주당 변재일 의원이 7일 K...
# Processing label: 3
# Processing text: 김건희, 美매체 인터뷰 "난 尹정부 '조력자'…예술이 정치·경제·외교 문제 푸는데 역할" ...
# Processing label: 0
# Processing text: 尹 정상회담 전날 “좀 마십시다” 건배사? 與 “가짜뉴스” 유튜버 고발 유튜버 '고양이뉴스...
# Processing label: 5
# Processing text: ‘방탄’ 하느라 11개월 풀가동 국회, 이번주는 쉽니다 11개월 동안 쉬지 않고 열렸던 국...
# Processing label: 0
# Processing text: [속보]북한, 전승절 '무장장비전시회' 개최… 김정은, 러 국방장관과 참관         ...
# Processing label: 0
# Processing text: 민주 “온 나라가 극우…국정 돌파 방안이 태극기부대뿐인가” 이재명 더불어민주당 대표가 30...
# Processing label: 1
# Processing text: 외교부, 中대사 초치… “외교사절 본분 맞게 처신하라” 싱하이밍 주한 중국대사(오른쪽)와 ...
# Processing label: 5
# Processing text: 김기현 "美서 관용차에 딸 5분 태운건데…질책 달게 받겠다" 김기현 국민의힘 대표는 18일...
# Processing label: 0
# Processing text: 한일정상회담 여론 평가, '성과 없었다'가 절반 육박 윤석열 대통령과 기시다 후미오 일본 ...
# Processing label: 2
# Processing text: 中 대사 “美 승리에 베팅, 나중에 반드시 후회” 더불어민주당 이재명(왼쪽) 대표와 싱하이...
# Processing label: 1
# Processing text: 尹 “반국가 세력들, 北제재 해제 읍소하고 종전선언 합창” 윤석열 대통령이 28일 서울 중...
# Processing label: 5
# Processing text: 민주, ‘나경원-볼턴’ 사례로 외교부 ‘오염수 서한 유감 표명’ 비판 박광온 더불어민주당 ...
# Processing label: 2
# Processing text: 與윤리위 "골프 논란 홍준표 징계 개시여부 20일 결정" 국민의힘 윤리위원회가 전국적으로 ...
# Processing label: 2
# Processing text: 윤 대통령, 소금 사재기 두고 "정치·사업 목적으로 선동 세력있어" 윤석열 대통령이 일본 ...
# Processing label: 4
# Processing text: 위기의 김규현 김규현 국가정보원장이 31일 오후 서울 여의도 국회에서 열린 정보위원회 전체...
# Processing label: 3
# Processing text: 감사원장, 감사위원 열람 결재 ‘전산 조작’ 시인 유병호 감사원 사무총장(오른쪽)이 29일...
# Processing label: 2
# Processing text: 이재명, 尹대통령 "사기꾼" 발언에 "저를 포함해 국민들 자괴감 느껴" 이재명 더불어민주당...
# Processing label: 1
# Processing text: “사고 나 죽어라”... 개딸들, 쇄신 요구 野 청년 정치인에 저주 퍼부어 이재명 대표 극...
# Processing label: 0
# Processing text: 野 “나라가 온통 극우” 공격하자… 대통령실 “야당 국가관은 뭐냐” 대통령실은 30일 윤석...
# Processing label: 4
# Processing text: 박지원 "이낙연 왜 한가하게 돌아다니나…이재명부터 만나라" 박지원 전 국가정보원장(국정원장...
# Processing label: 2
# Processing text: 경북도, 재난 취약지역 관리체계 혁신…"인공지능·드론 활용"         28일 경북 북...
# Processing label: 3
# Processing text: 민주당 "민심 이반…대통령실 전면 인적쇄신 필요" 더불어민주당이 최근 대통령실의 오염수, ...
# Processing label: 1
# Processing text: 경북·구미 방산혁신 클러스터 지역협의회 첫 개최             제1회 '경북·구미 ...
# Processing label: 0
# Processing text: 비명, 의총서 “이재명 사퇴하라”... 친명 “그만해라” 야유 이재명 더불어민주당 대표(오...
# Processing label: 0
# Processing text: 최재형 “민주당, 천안함 망언 사과로 넘어갈 일 아냐” 국민의힘 최재형 의원은 8일 “민주...
# Processing label: 0
# Processing text: 김건희 "한일간 더욱 풍성한 교류 이뤄지길 기대"…기시다 영부인과 리움미술관 방문 윤석열 ...
# Processing label: 0
# Processing text: 대통령실, 이상민 선고에 “거야 탄핵소추권 남용, 심판 받을 것” 대통령실은 25일 헌법재...
# Processing label: 4
# Processing text: 윤 대통령 “폴란드와 공조해 우크라 재건”…방산·원전 협력도 폴란드를 공식 방문 중인 윤석...
# Processing label: 3
# Processing text: 尹대통령, 오후 젤렌스키와 정상회담... 우크라 지원 등 협의 지난 20일 오후 7국(G7...
# Processing label: 3
# Processing text: 한·미·일, 내달 18일 캠프 데이비드서 정상회의 윤석열 대통령과 조 바이든 미국 대통령,...
# Processing label: 0
# Processing text: 한동훈 "검찰이 증거 조작? 송영길, 당 대표까지 지낸 분이…" 한동훈 법무부 장관이 '더...
# Processing label: 4
# Processing text: 민주 44.2%, 국힘 36.8%…尹 지지율 2주연속 하락[리얼미터] 김기현 국민의힘 대표...
# Processing label: 0
# Processing text: 하태경 “김남국, 잡코인으로 돈세탁…투자 실패 아닌 30억 손에 쥐는 것” 가상자산(암호화...
# Processing label: 0
# Processing text: 마약 아니었다, 강화도서 발견된 北주민 시신에 있던 건 백반(白礬) 결정. /한국전통지식포...
# Processing label: 3
# Processing text: 尹 취임 1년에 유승민·안철수 잇달아 '경고' 오는 10일 윤석열 대통령 취임 1주년을 앞...
# Processing label: 2
# Processing text: 더 가까워지는 韓美日… 바이든, 尹·기시다에 워싱턴 3자회담 초청 21일 히로시마 G7 회...
# Processing label: 4
# Processing text: ‘브리핑 하면 안 가’…민주당 오염수 간담회에 원안위원장 불참 국회 과학기술정보방송통신위원...
# Processing label: 0
# Processing text: 해병대 '故 채수근 상병 사고' 조사결과 발표 돌연 연기        고(故) 채수근 해병...
# Processing label: 2
# Processing text: 이상민 기각' 내다본 여야…與 "법 위반 없어" 野 "재판관 성향" 이태원 참사' 부실 대...
# Processing label: 4
# Processing text: ‘가짜 독립유공자’ 서훈 박탈 추진…손혜원·김원웅 부친 재검토할듯 김원웅 전 광복회장이 재...
# Processing label: 4
# Processing text: 中, 유학생 단체 등 활용… 사드·후쿠시마 여론몰이 2014년 9월 전북 한 대학에서 '공...
# Processing label: 3
# Processing text: 대통령실 "尹 '지각' 가짜뉴스, 국내 선동세력이 왜곡된 정보 흘려" 윤석열 대통령이 프랑...
# Processing label: 4
# Processing text: GDP 250조' 우크라 재건에 2000조?…전쟁 나라에서 尹의 민망한 '잿밥 외교' 대통...
# Processing label: 1
# Processing text: 尹지지율, 3주 연속 하락…'잘한다' 36.6% '못한다' 59.9% [리얼미터] 윤석열 ...
# Processing label: 3
# Processing text: 野 “이동관, 갑질·악성 학부모 전형” 與 “발목잡기 본능 또 시작” 이동관 방송통신위원장...
# Processing label: 0
# Processing text: [속보] 윤 대통령 "묻지마식 범죄, 근본적 예방 방안 필요"         윤석열 대통령...
# Processing label: 5
# Processing text: 與 “21세기 천동설, 국제 망신” 野 “그로시, 방류 홍보대사 자처” 라파엘 그로시 국제...
# Processing label: 3
# Processing text: 유엔 참전용사 “그때로 다시 돌아가도 한국 지키는 선택할 것” 6·25 전쟁 정전 70년을...
# Processing label: 3
# Processing text: 북한 '무기 전시회'로 군 열병식 대체했나…오늘 밤 동향 주목        (평양 노동신문...
# Processing label: 0
# Processing text: 외교2차관, 유네스코 사무부총장 만나 "한·유네스코 협력 발전"         오영주 외교...
# Processing label: 0
# Processing text: 조민, 유튜브 첫 영상 게시 "오겹살 좋아하고, 닭발 좋아하고, 껍데기도 좋아해요" 조국 ...
# Processing label: 0
# Processing text: 한국·유엔 22국 vs 北·中·러… 전혀 다른 ‘정전 70년’ 북한이 오는 27일 6·25...
# Processing label: 0
# Processing text: 답답한 尹대통령, 개각 앞두고 "사람 찾기가 이리도 어려우냐" 한탄 윤석열 대통령이 이르면...
# Processing label: 2
# Processing text: 북한, 장애인 체전 개최…'체육 중시' 기조 확산에 주력         (평양 노동신문=뉴...
# Processing label: 0
# Processing text: 이재명 "당 단합 중요, 도와달라" vs 이낙연 "혁신 필요, 도덕성 회복해야" 이재명 더...
# Processing label: 0
# Processing text: 한ㆍ미ㆍ일 정상, 다음달 워싱턴 아닌 제3장소서 동맹 외치나 다음 달 중 미국에서 열리는 ...
# Processing label: 4
# Processing text: 野, 서울-양평고속도로 국정조사 요구서 제출키로…권영세는 윤리위 제소 더불어민주당이 오는 ...
# Processing label: 2
# Processing text: "또 넘칠라"…더 커진 '괴산댐→다목적댐' 전환 목소리         충북 괴산군 칠성면 ...
# Processing label: 3
# Processing text: 김정은, '공격용 무인기' 시험비행 시찰했다…'기밀 행보' 첫 확인         (평양 ...
# Processing label: 0
# Processing text: 서이초 교사 사망도 '카르텔' 때문?…유승민 "사교육 때려잡는다고 공교육 바로 서는 것 아...
# Processing label: 2
# Processing text: 이재명, 내일 싱하이밍 만난다...“日오염수 공동대응 논의” 이재명 더불어민주당 대표가 지...
# Processing label: 0
# Processing text: 이재명 "오염수·양평·이동관 지명까지…국민과 싸우려는 정부·여당"         이재명 더...
# Processing label: 1
# Processing text: 尹호위무사' 이용, 김건희 명품숍 방문은 "리투아니아 문화 탐방…하나의 외교로 적절" 영부...
# Processing label: 3
# Processing text: 트뤼도, 산불 진화 도운 韓 구호대에 감사 인사… "모두가 감동"         저스틴 트...
# Processing label: 3
# Processing text: 당정대 "재난대응시스템 근본 개편…'기후 재난 대응 TF' 구성"(종합)         김...
# Processing label: 4
# Processing text: 검찰개혁 역행' 논란에 법무부 "개혁이 불편 초래하면 바로 잡아야" [문답]        ...
# Processing label: 0
# Processing text: [속보]북한 '무장장비전시회-2023' 개최… 신형 무인 정찰기 공개        (평양 ...
# Processing label: 0
# Processing text: 류호정 “배꼽티가 탈코르셋 어긴 것? 또 다른 구속” 퀴어축제에 참석한 류호정 의원. /류...
# Processing label: 0
# Processing text: 추미애 "한동훈 '폰 분실' 사건? 경찰청장이 옷 벗고 결기 보여줘야 할 사안" 한동훈 법...
# Processing label: 1
# Processing text: 윤 대통령, 기시다에 오염수 정보 공유·한국 전문가 참여 요청 윤석열 대통령과 기시다 후미...
# Processing label: 5
# ...
# Processing label: 0
# Processing text: 수해에 베트남 간 野의원들, 귀국때 사과하며 “尹 재난 감수성 제로” 더불어민주당 박정 의...
# Processing label: 1
# Processing text: 안철수 "尹, 장마 끝나고 우크라 비밀리에 전격 방문했으면…" 국민의힘 안철수 의원이 윤석...
# Processing label: 2
# Processing text: 6·25 전사 ‘일병 형제’, 尹 지켜보는 가운데 현충원에 함께 묻혔다 윤석열 대통령이 6...
# Processing label: 4
# Processing text: 국힘 당무감사위, 오늘 '수해 워크숍' 강성만 진상조사 돌입         신의진 국민의힘...
# Processing label: 0
# Processing text: 국힘 "민노총·전장연·대진연 3대 폭력시위 단체…보조금 제한 복원"         하태경 ...
# Processing label: 0
# Processing text: [속보] 尹 "비통한 마음…특별재난지역 선포 등 정책 모두 동원" 6박 8일 간의 해외 순...
# Processing label: 4
# Processing text: 尹대통령 "기상 이변 어쩔 수 없다는 인식 뜯어고쳐야" 순방을 마치고 귀국한 윤석열 대통령...
# Processing label: 5
# Processing text: 국힘 '우주항공청' 과방위 단독 개의…민주, 안조위 신청 맞불         장제원 국회 ...
# Processing label: 2
# Processing text: 윤석열차 논란' 만화진흥원, 공모결격 사유서 '정치적 의도' 삭제 한국만화영상진흥원(만진원...
# Processing label: 3
# Processing text: 국민의힘 '횟집 회식하기 운동' 돌입 '먹어서 응원하자'? 일본 후쿠시마 오염수 방류 문제...
# Processing label: 5
# Processing text: 검찰 "윤관석 의원 등이 9400만원 살포"…野현역 의원 10~20명 검찰 수사 선상에 더...
# Processing label: 0
# Processing text: “일 안 해도 월급보다 더 줘”… 실업급여 제도 손본다 임이자 국민의힘 노동개혁특위원장이 ...
# Processing label: 4
# Processing text: “신의 직장 위에 文의 직장, 알박기 인사 이젠 퇴장할 시간” 박대출 국민의힘 의원이 9일...
# Processing label: 4
# Processing text: 검찰, '50억 클럽' 박영수 전 특검 딸·아내 압수수색 등 강제 수사 착수 검찰이 대장동...
# Processing label: 0
# Processing text: 온유한 줄로만 알았는데…김기현 '단칼 리더십' 눈길        김기현 국민의힘 대표. 2...
# Processing label: 4
# Processing text: 국힘 법사위원, '선거법 공백 책임' 민주 비판에 "왜곡"         1일 서울 합정역...
# Processing label: 0
# Processing text: "생즉사 사즉생 정신으로 연대"…尹·젤렌스키 협력 굳건해졌다 극비리에 우크라이나를 전격 방...
# Processing label: 5
# Processing text: [속보] 한미일 외교장관, 북한 ICBM '강력 규탄' 공동성명 한미일 외교장관이 14일 ...
# Processing label: 3
# Processing text: 野, ‘노란봉투법 본회의 직회부’ 환노위서 단독 의결 더불어민주당과 정의당 등 야당이 24...
# Processing label: 0
# Processing text: 北 “美 정찰기 영공 침범”…합참 “허위 사실로 긴장 조성 말라” 미국 정찰기가 북한 영공...
# Processing label: 3
# Processing text: 장제원, '우주항공청법' 안조위 수용…"모든 책임은 민주당"         장제원 국회 과...
# Processing label: 0
# Processing text: 국힘, 철근 누락 아파트 진상조사TF…"국정조사 검토"(상보)         윤재옥 국민의...
# Processing label: 0
# Processing text: “교육당국·사교육 이권 카르텔”... 尹 교육개혁의 신호탄 윤석열 대통령이 5월 31일 청...
# Processing label: 4
# Processing text: 野 "'폭우 골프' 홍준표 감찰하라"…洪 "대구 수해 피해 없었다" 민주당 대구시당이 전국...
# Processing label: 0
# Processing text: 골프보다 '입'이 화 불렀다…'당원권 정지' 체면구긴 홍준표 국민의힘 중앙윤리위원회(위원장...
# Processing label: 2
# Processing text: 여 조강특위 면접…김성태 "초심으로" 이용호 "수도권서 승리 기여"         배현진 ...
# Processing label: 0
# Processing text: 김영록 지사, 여수·광양 수소배관망 구축 예타 선정 건의         한덕수 국무총리와 ...
# Processing label: 0
# Processing text: 당정 "차별 없는 급식 제공 조속 추진…'유보 일원화' 체감"(1보)         김기현...
# Processing label: 4
# Processing text: 윤 “상반기 165억달러 투자유치…영업사원 성과 나타나” 윤석열 대통령이 27일 용산 대통...
# Processing label: 5
# Processing text: 나토 가는 윤 대통령 “북한의 불법적 행위 맞서 국제사회 공조” 윤석열 대통령이 지난 4월...
# Processing label: 3
# Processing text: 尹대통령 "해외서 소식 듣고 산이 무너져 민가 덮친 모양이라 생각했는데…" 순방을 마치고 ...
# Processing label: 5
# Processing text: [속보] 윤 대통령 "규칙 위반 학생 방치…범법행위 방치와 같아"         윤석열 대...
# Processing label: 5
# Processing text: 신평, 홍준표 겨냥 "尹, 전율할 정도로 무서운 자기억제력…'너 좋고 나 좋고' 식 안될 ...
# Processing label: 4
# Processing text: 윤 대통령 “힘을 통한 평화가 가장 확실, 제재로 북핵 막아야” 윤석열 대통령은 10일 “...
# Processing label: 3
# Processing text: 양평고속道 사과 요구에…원희룡 "이재명·이해찬부터 사과해야" 원희룡 국토교통부 장관이 26...
# Processing label: 4
# Processing text: 본색 드러낸 진보당 강성희 “이승만은 내란 목적 살인죄 수괴” 진보당 강성희 “이승만도 내...
# Processing label: 3
# Processing text: 박진 장관, IAEA 사무총장 만나 “안전성 검증 위한 협조 요청” 박진 외교부 장관이 8...
# Processing label: 4
# Processing text: 김기현 "尹 순방 연기? 오래전 논의…野 좁쌀같은 눈으로 트집" 김기현 국민의힘 대표는 1...
# Processing label: 0
# Processing text: 산불 골프 논란' 김진태 "강원도 틀어박혀 연구만 해…그냥 좀 내버려 둬" 산불 진화 중 ...
# Processing label: 0
# Processing text: 민주 지지율 29%... 尹정부 출범 후 최저 수준 [한국갤럽] 이재명 더불어민주당 대표(...
# Processing label: 0
# Processing text: 한미일, 3국 정상회의 정례화 실무협의…정상들 만남서 확정할 듯(종합)         조현...
# Processing label: 4
# Processing text: 美워싱턴서 정전협정 70주년 기념식…"참전용사 희생·봉사로 한미동맹 시작"         ...
# Processing label: 0
# Processing text: 일부 감사위원, 전현희에 불리한 감사 보고서 내용 축소·삭제 시도 전현희  감사원의 일부 ...
# Processing label: 2
# Processing text: 광우병 시위 주도자 “당시 팩트엔 관심 없었다, 오염수 괴담도 판박이” “미국산 소고기 수...
# Processing label: 0
# Processing text: 장예찬 "이동관 자녀 학폭, 우려 문자 1천통 왔다…걱정 많이 하더라" 방송통신위원장으로 ...
# Processing label: 0
# Processing text: 윤 대통령 "국민안전 도외시한 이권 카르텔 깨부숴야"         윤석열 대통령    윤...
# Processing label: 5
# Processing text: 박범계 "법무부 장관답게 하라" 한동훈 "훈계하지 마시라" 충돌(종합)         한동...
# Processing label: 0
# Processing text: 귀국 윤 대통령 “공무원들 호우 때 앉아있지 말고 현장 나가라” 6박8일간의 순방을 마치고...
# Processing label: 3
# Processing text: 선관위 때린 尹대통령 "선관위, 아직까지도 정신 못차려" 중앙선거관리위원회(선관위)가 자녀...
# Processing label: 4
# Processing text: 尹 멘토 신평 "조민 판결 '슬픈 일'이라 하니 與에서 집단 공격…무간지옥 된 정치" 윤석...
# Processing label: 0
# Processing text: 국힘, 이동관 후보자 철벽 방어…청문회 대비 사보임         이동관 방송통신위원장 후...
# Processing label: 0
# Processing text: 김건희 특혜 의혹'에 사업 자체를 '폐기'해버린 원희룡 "날파리 선동 차단" 원희룡 국토교...
# Processing label: 2
# Processing text: [단독]감사원 '文정부 통계 의혹' 장하성 소환…내주 김현미 조사 문재인 정부의 통계조작 ...
# Processing label: 4
# Processing text: ‘먹방 응원’…오염수 논란에 횟집 찾는 국힘, 다음은 성주 참외 국민의힘 윤재옥 원내대표가...
# Processing label: 0
# Processing text: 김기현 "대중국 무역 10조원 적자, 경제적으로 미국에 더 큰 비중 둬야" 국민의힘 김기현...
# Processing label: 4
# Processing text: 김기현 “호남서 ‘볼매’ 인정받겠다…지역구보다 더 많이 찾아” 김기현 국민의힘 대표는 27...
# Processing label: 0
# Processing text: 한일 정상회담, 후쿠시마 오염수 문제 논의하나…실제 방류 미뤄질 수도 한국에 방문하는 기시...
# Processing label: 0
# Processing text: “5월 정신은 자유민주주의 실천 명령” 비 맞으며 ‘임을 위한 행진곡’ 불러 - 윤석열 대...
# Processing label: 5
# Processing text: 尹대통령 “학교서 다루지 않은 내용, 수능 출제 배제해야” 윤석열 대통령./대통령실  윤석...
# Processing label: 4
# Processing text: 국힘 “민주라는 단어 사리사욕·방종·폭주 명분 되지 않도록 할 것” 강민국 국민의힘 수석대...
# Processing label: 0
# Processing text: 코인 중독'?…"김남국, '국회 상임위 회의' 와중에도 위믹스 팔아" 거액의 가상 화페 보...
# Processing label: 0
# Processing text: 원희룡 "양평고속道, 이해찬·이재명이 거짓 선동" 野 "친구냐" 원희룡 국토교통부 장관이 ...
# Processing label: 4
# Processing text: 박성중 "방송계 숙청 정도, 文에 비하면 MB는 약과…이동관 우려 '기우'"        ...
# Processing label: 4
# Processing text: 대통령실 "김건희 민생 행보"…"산오징어 광어회 등 해산물 시식" 윤석열 대통령의 배우자 ...
# Processing label: 4
# Processing text: 장예찬 “정청래 야유 고성 저질쇼, 이재명이 좋아하니 하는 것” 장예찬 국민의힘 청년최고위...
# Processing label: 0
# Processing text: 김재원 "홍문종은 수해골프로 제명…홍준표 골프는 더 충격적" 김재원 국민의힘 최고위원이 최...
# Processing label: 2
# Processing text: 野 탈당' 김남국 "가난 코스프레 안했다…대선자금 세탁? 허위" 거액의 가상자산(코인) 보...
# Processing label: 0
# Processing text: 건국 대통령을 ‘내란 수괴’라고 한 국회의원[기자수첩] 진보당 강성희(왼쪽) 의원이 22일...
# Processing label: 0
# Processing text: ‘文때 홀대’ 천안함 老母·천안함장, 尹은 옆에 앉혀 예우했다 윤석열 대통령과 김건희 여사...
# Processing label: 5
# Processing text: “이재명, 정치하면 안 된다고 생각” 이기인이 말한 성남 스케이트장 사건 2013년 이재명...
# Processing label: 0
# Processing text: 대통령실, 이래경 ‘尹 CIA 면담’ 발언에 “한미동맹 저해하는 음모론” 이재명 민주당 대...
# Processing label: 5
# Processing text: 1세대 영어 강사 오성식 "윤 대통령, 스피치 얼마나 잘하는지 소름 끼쳐" 1세대 유명 영...
# Processing label: 4
# Processing text: 유승민 "尹, 총선에 노골적 개입할 것…'친윤 공천', 수도권서 통할지 회의" 유승민 전 ...
# Processing label: 1
# Processing text: 하태경 “홍준표, 중징계는 없을 것… 골프 불온시하는 문화 바뀌어야” 하태경 국민의힘 의원...
# Processing label: 0
# Processing text: 김기현 "교사 극단선택 與 의원 연루? 김어준 심판대 세울 것" 국민의힘은 21일 "더불어...
# Processing label: 0
# Processing text: “中에 굴종 외교” 김기현이 비판한 순간, 이재명 웃음 터뜨렸다 20일 국회에서 진행된 교...
# Processing label: 0
# Processing text: 한미일 정상회담서 '오염수 가짜뉴스' 논의?… 역효과 우려도        왼쪽부터 조 바이...
# Processing label: 0
# Processing text: 민주, 실업급여 하한 축소 검토에 “부정수급 막는 건 맞지만…” 국민의힘 박대출 정책위의장...
# Processing label: 0
# Processing text: 민주유공자법 대상 아닌데…박민식 “박원순, 유공자로 부활할 수도” 박민식 국가보훈부 장관(...
# Processing label: 0
# Processing text: 정전 70주년' 국힘 "민주, 더러운평화론·보좌진 국보법 위반" 비판         김기현...
# Processing label: 0
# Processing text: 윤, 차관 내정자들에 “약탈적 이권카르텔에 맞서 싸워달라” 윤석열 대통령이 지난 28일 서...
# Processing label: 4
# Processing text: 함께 피흘린 그날처럼… 유엔 참전 22국, 한국서 재회 6·25전쟁 때 유엔군 자격으로 참...
# Processing label: 3
# Processing text: 탈당, 체포, 고양갑 흔들…故노회찬 5주기 앞둔 위기의 정의당 정의당이 고(故) 노회찬 전...
# Processing label: 0
# Processing text: 與특위 “전장연 등 3개 시민단체, 박원순 서울시와 유착해 10년간 2239억 챙겨” 박경...
# Processing label: 5
# Processing text: 국힘 “민주노총, 불법 폭력의 제왕”…시민단체 보조금 제한 추진 하태경 국민의힘 시민단체 ...
# Processing label: 0
# Processing text: 與, '코인 의원' 11명 유출되자 고발…野 "김남국 때랑 다르네" 국민의힘이 국회의원 가...
# Processing label: 0
# Processing text: 김문수, '피철철' 노동자 곤봉 진압에 "경찰이 당연히 해야 될 일" 한국노총의 경사노위 ...
# Processing label: 5
# Processing text: 김기현 “이재명의 김남국 구하기, ‘도원결의’ 능가하는 코인결의” 김기현 국민의힘 대표(왼...
# Processing label: 0
# Processing text: 尹, 5월 어머니와 함께 입장...주먹 흔들며 ‘임을 위한 행진곡’ 불렀다 윤석열 대통령이...
# Processing label: 5
# Processing text: 與 “송영길 조여오는 수사에 조급...정치쇼는 언젠가 진실 드러나” 송영길 전 더불어민주당...
# Processing label: 0
# Processing text: [단독] 文때 시위대에 다친 경찰 400명, 소송은 1건 문재인 정부가 출범한 이래 국가에...
# Processing label: 0
# Processing text: 김기현 "건축 이권카르텔 배후 찾는 국정조사 추진하겠다"         김기현 국민의힘 대...
# Processing label: 0
# Processing text: 국민의힘의 '별게 다 상호주의' △김기현 국민의힘 대표가 20일 국회 교섭단체 대표 연설에...
# Processing label: 0
# Processing text: 尹대통령 "지난 정부 400조 채무, 사기·착취 행위" 윤석열 대통령은 13일 "국민의 혈...
# Processing label: 5
# Processing text: 김기현 "中 대사 심각한 외교 결례…강력 유감" 김기현 국민의힘 대표가 이재명 더불어민주당...
# Processing label: 0
# Processing text: [단독]'OOO에 지원금' 황당 비공개...이런 통일부 '청 격하' 경고 윤석열 대통령이 ...
# Processing label: 4
# Processing text: 국정개입' 논란 풍수학자 "'악어상' 尹, 시대 부름 받은 관상" 대통령 관저 선정 과정에...
# Processing label: 5
# Processing text: 尹대통령, 또 "이권 카르텔의 부당이득, 낱낱이 걷어내야" 윤석열 대통령이 하반기 경제정책...
# Processing label: 4
# Processing text: 與 국방위원들 "사드 정상화 지연 의혹, 文·이해찬 조사해야" 국회 국방위원회 소속 국민의...
# Processing label: 0
# Processing text: 박대출 "노무현 정부 때 세종시 풍수지리학자가 자문…풍수지리도 내로남불인가" 지난해 윤석열...
# Processing label: 4
# Processing text: 與, 이래경·천안함 논란 '총공세'…"민주당은 북한 정당이냐" 국민의힘이 이래경 더불어민주...
# Processing label: 0
# Processing text: 尹우크라행 "현장 피부로 느끼기 위해"…호우엔 "당장 서울 뛰어가도 상황 못바꿔" "(윤석...
# Processing label: 5
# Processing text: 美 보수 한인단체 "한반도평화법안, 가짜평화 구상…실패할 것"          보수 성향 ...
# Processing label: 0
# Processing text: 尹, 이번엔 ‘연구비 카르텔’ 조준 “年 30조 R&D 예산 원점 재검토” 연간 30조원에...
# Processing label: 5
# Processing text: 前천안함장 “부하들 죽인게 나인가 北인가” 이재명에 따져물었다 이재명 더불어민주당 대표가 ...
# Processing label: 0
# Processing text: 尹대통령, 美전략핵잠수함 올랐다…北 무력시위 맞불? 북한이 단거리 탄도미사일 발사로 무력시...
# Processing label: 3
# Processing text: 외교부 "北 불법적 핵·미사일 개발 용납해선 안 돼"         (외교부 제공) 202...
# Processing label: 3
# Processing text: 내달 18일 한미일 정상회의…美 "3국간 군사협력 더 열정적으로" 윤석열 대통령과 조 바이...
# Processing label: 5
# Processing text: 누워 자고, 책 읽고, 이어폰 끼고…민주당의 이상한 ‘철야 농성’ 지난 6일 오후 11시쯤...
# Processing label: 5
# Processing text: 野, 尹순방 비판하더니... 강기정, 수해 우려에도 10박 12일 유럽출장 강기정 광주시장...
# Processing label: 0
# Processing text: 이상민 탄핵 기각에 국민의힘 "민주당 지도부야말로 탄핵 대상" 헌법재판소가 이상민 행정안전...
# Processing label: 0
# Processing text: 윤 대통령, 룩셈부르크 총리 만나 퀀텀 협력·북핵 공조 논의(종합)         윤석열 ...
# Processing label: 3
# Processing text: "한미일 3국 간 훈련 '지속' 위한 제도적 장치 필요"         전북대 진수당에서 ...
# Processing label: 0
# Processing text: 김기현 "양평고속도는 민주당 자살골…사고 친 사람이 사과해야" 김기현 국민의힘 대표는 11...
# Processing label: 0
# Processing text: 용산 "북한 지령 받는 간첩들, 공적 기관에 스며들었다" 김대기 대통령 비서실장이 "북한 ...
# Processing label: 4
# Processing text: 김기현 "민주당 지도부야말로 탄핵 대상…사죄 마땅하다"         김기현 국민의힘 대표...
# Processing label: 0
# Processing text: [속보]윤 "대한민국, 한미동맹 핵심축으로 세계 자유·평화·번영 노력"         6·...
# Processing label: 5
# Processing text: 우크라 방문 130분전 “노트북 닫아달라, 대통령 신변 걸린 일” “기자분들, 노트북 닫아...
# Processing label: 5
# Processing text: 與 시민단체특위 “전장연 포함 3개 단체 10년간 서울시 지원금 2239억 독점” 하태경 ...
# Processing label: 5
# Processing text: 與, 시민단체 정상화 TF 만든다 국민의힘이 당 산하에 가칭 ‘시민단체 정상화 태스크포스(...
# Processing label: 0
# Processing text: 조민 소송 취하에…이준석 "조국 총선 출마 위한 사전 준비" 이준석 전 국민의힘 대표가 조...
# Processing label: 0
# Processing text: 대통령실 “탈북민 급증 추세… 과거 정부 5년과 큰 차이” 용산 대통령실 전경. /뉴스1 ...
# Processing label: 4
# Processing text: [속보] 윤 대통령 "국민안전 도외시한 이권카르텔 깨부숴야…엄정 제재"         윤석...
# Processing label: 5
# Processing text: “빈살만은 벤츠, 伊총리는 마세라티… 프랑스, 尹만 싸구려車 홀대” 또 가짜뉴스 부산엑스포...
# Processing label: 5
# Processing text: 절망한 20대 교사…與 "교권보호법, 민주당 반대로 막혔다" 지난 18일 서울 강남 초등학...
# Processing label: 0
# Processing text: 시럽급여' 논란에 윤재옥 "이야기 않겠다…언론 지적 알고 있다" 국민의힘 윤재옥 원내대표가...
# Processing label: 0
# Processing text: 망신 자초한 이재명... 교수단체 “짜장면이 목구멍 넘어가던가” 이재명 더불어민주당 대표가...
# Processing label: 0
# Processing text: 尹대통령 "재정지출 늘려라? 전형적인 미래세대 약탈" 윤석열 대통령은 28일 "일각에서는 ...
# Processing label: 5
# Processing text: 양평고속道 국정조사 요구에 국민의힘 "가짜뉴스로 이재명 방탄하려는 것" 더불어민주당이 서울...
# Processing label: 0
# Processing text: 순방 중 호우 챙긴 尹 "저지대 통제는 무리하다 싶을 정도로" 윤석열 대통령은 16일(현지...
# Processing label: 5
# Processing text: 천안함 막말 겨눈 尹 “영웅들 희생 왜곡·폄훼는 반국가행위” 윤석열 대통령이 2023년 6...
# Processing label: 5
# Processing text: [기자수첩] ‘핼러윈 참사’ 가슴엔 근조 리본, 두손은 코인 거래 김남국 더불어민주당 의원...
# Processing label: 0
# Processing text: "장마철엔 핵실험 어렵고…" 돌연 EEZ 꺼낸 北, 억지주장 속내 미군의 정찰기가 북한의 ...
# Processing label: 3
# Processing text: 돌아온 '1타강사' 원희룡 "野 거짓선동…양평 4년 뒤 재추진" 원희룡 국토교통부 장관이 ...
# Processing label: 3
# Processing text: 윤두현, 이재명 저격…"우리 어민 죽이는 거짓주장 사과하라" 윤두현 국민의힘 의원이 후쿠시...
# Processing label: 0
# Processing text: 尹 “민간단체 보조금 부패 카르텔 부술 것” 윤석열 대통령이 13일 오전 서울 용산 대통령...
# Processing label: 5
# Processing text: 엄중경고' 받은 이주호 '납작'…"입시 수도없이 연구한 대통령, 제가 많이 배워" 윤석열 ...
# Processing label: 5
# Processing text: 김건희 사진 악플'에 박민식 "천번이고 안아주고 만번이고 눈 맞춰야" 박민식 보훈처장이 윤...
# Processing label: 0
# Processing text: 한미 "北, 핵공격 하면 정권 종말로 이어질 것" 김태효 국가안보실 1차장은 18일 커트 ...
# Processing label: 3
# Processing text: 與 “이재명‧中대사 회동 삼전도 굴욕 떠올라, 중국몽에서 깨어나라” 지난 8일, 서울 성북...
# Processing label: 0
# Processing text: 尹대통령 “민간단체 보조금, 단 한푼 혈세도 낭비 없도록 후속 조치” 윤석열 대통령이 지난...
# Processing label: 5
# Processing text: 방미 길 오른 김기현 "백악관·의회 찾아 한미 동맹 강화 모색" 방미 길에 오른 김기현 국...
# Processing label: 5
# Processing text: 與 "교권 붕괴하는 동안 진보교육감들 뭘 하고 있었는가" 박대출 국민의힘 정책위의장이 20...
# Processing label: 0
# Processing text: 국민의힘, '오염수 안전성' 강조 전력…당 TF에 친윤계 의원모임까지 국민의힘이 당 특별위...
# Processing label: 0
# Processing text: 김여정, 9시간 만에 두 번째 담화…“미군 위태로움 경험할 것” 김여정 조선노동당 중앙위원...
# Processing label: 3
# Processing text: 尹대통령, 북·러 겨냥 "전체주의·권위주의 세력이 위협 조장" 리투아니아를 방문 중인 윤석...
# Processing label: 5
# Processing text: 국힘 "노인 존재 부정하는 민주당 DNA…김은경, 즉각 사퇴해야"         윤재옥 국...
# Processing label: 0
# Processing text: 尹, 폴란드행 열차서 집중호우 긴급회의…귀국길엔 중대본 회의예정 윤석열 대통령은 15일(현...
# Processing label: 5
# Processing text: 미 북부사령관 지명자 "北 탄도미사일 탐지·요격 능력 강화할 것"         그레고리 ...
# Processing label: 3
# Processing text: 윤 대통령, 방통위원장에 이동관 지명…"공정한 미디어 복원할 것"(종합)         이...
# Processing label: 5
# Processing text: 이재명 “더러운 평화가 전쟁보단 낫다” 신원식 “이완용이 했던 말” 국민의힘 신원식(왼쪽)...
# Processing label: 4
# Processing text: 북한, 90일 만에 ICBM 발사…윤 대통령 “도발 묵과할 수 없어” 윤석열 대통령이 12...
# Processing label: 3
# Processing text: 尹대통령 "일자리는 정부 아닌 기업이 만드는 것" 윤석열 대통령은 27일 "일자리는 정부의...
# Processing label: 4
# Processing text: 김기현, 이틀만에 또…"민주당, 괴담 마약 중독된 괴물" 국민의힘이 더불어민주당의 후쿠시마...
# Processing label: 5
# Processing text: 與 "민주당, 이실직고하라…양평고속道 대안 노선 먼저 주장" 국민의힘은 8일 "지금이라도 ...
# Processing label: 3
# Processing text: 文때 연 4000억씩 늘어난 민간 보조금... 尹 “말도 안되는 정치보조금 없애야” 윤석열...
# Processing label: 5
# Processing text: 정부 "IAEA에 '100만달러 뇌물' 가짜뉴스 언급, 국제적 부적절" 박구연 국무조정실 ...
# Processing label: 4
# Processing text: 국민의힘, 尹 자유총연맹 연설 옹호…"팩트에 근거" 윤석열 대통령이 자유총연맹 창립 기념식...
# Processing label: 5
# Processing text: 조태용 안보실장 "누가 적인지, 우리편인지 분명한 인식해야" 조태용 대통령실 외교안보실장이...
# Processing label: 5
# Processing text: 대통령실 “거야의 탄핵소추권 남용, 국민 심판받을 것” 서울 용산 대통령실 청사 전경./뉴...
# Processing label: 5
# Processing text: 제2 LH… 태양광 공무원이 태양광 장사 문재인 정부의 신재생에너지 확대 정책에 편승해 태...
# Processing label: 2
# Processing text: 박주민 "연좌농성 모욕"…한동훈 "모욕 당한 건 우리 '사법시스템'" 한동훈 법무장관이 더...
# Processing label: 4
# Processing text: 원희룡 "양평 道, 민주당의 '기승전-김건희' 공세로 4년 뒤로 미루는 것" 원희룡 국토교...
# Processing label: 5
# Processing text: 국민의힘, 日오염수에도 "수산물 방사능 오염 없어…맛있게 드셔달라" 국민의힘 '우리바다 지...
# Processing label: 0
# Processing text: 前천안함장 “제 부하 죽인 건 北 만행이죠?” 이재명에 물었다 더불어민주당 이재명(왼쪽) ...
# Processing label: 0
# Processing text: 국힘, 과방위 잇단 파행에 "민주, 우주강국 가는 길 막지 말라"(종합)         윤...
# Processing label: 5
# Processing text: 尹대통령 "반국가세력이 종전선언 노래부르고 다녀" 윤석열 대통령은 28일 "북한이 다시 침...
# Processing label: 5
# Processing text: 文정부 사드 고의 지연? 與 "안보 주권 포기" 野 "전임 탓 그만" 국민의힘이 문재인 정...
# Processing label: 0
# Processing text: [단독] 공수처, 예산 280억 쓰고 기소 단 3건…3000여건 검경 넘겼다 남기명 공수처...
# Processing label: 0
# Processing text: “땅 대표” 김기현 연설 방해한 정청래…이재명은 옆에서 웃고 있었다 정청래 더불어민주당 최...
# Processing label: 0
# Processing text: [단독] 文정부, 지방선거 압승뒤 지자체 '깜깜이 대북지원' 길 텄다 통일부가 2018년 ...
# Processing label: 4
# Processing text: 수해 복구' 당정, 또 당정…'민생 안정' 박차 가하는 국민의힘         김대기 대통...
# Processing label: 5
# Processing text: 한미일 정상회담과 '역대급' 한미훈련… 北 8월에도 '도발' 이어갈 듯        왼쪽부...
# Processing label: 5
# Processing text: 尹대통령, 첫 개각 “약탈적 이권 카르텔과 맞서 싸워달라” 김영호(왼쪽) 신임 통일부 장관...
# Processing label: 5
# Processing text: 韓中 관계의 ‘시한폭탄’… 국장급 중국대사 싱하이밍의 무례 싱하이밍 중국 대사  2020년...
# Processing label: 5

# %% [markdown]
# ### 데이터로더 초기화

# %% [markdown]
# #### 데이터패딩

# %%
class IterableDatasetPad(torch.utils.data.IterableDataset):
    def __init__(
        self,
        dataset: torch.utils.data.IterableDataset,
        batch_size: int = 1,
        num_devices: int = 1,
        seed: int = 0,
    ):
        self.dataset = dataset
        self.batch_size = batch_size
        self.seed = seed
        self.num_examples = 0

        chunk_size = self.batch_size * num_devices
        length = len(dataset)
        self.length = length + (chunk_size - length % chunk_size)

    def __len__(self):
        return self.length

    def __iter__(self):
        self.num_examples = 0
        if (
            not hasattr(self.dataset, "set_epoch")
            and hasattr(self.dataset, "generator")
            and isinstance(self.dataset.generator, torch.Generator)
        ):
            self.dataset.generator.manual_seed(self.seed + self.epoch)

        first_batch = None
        current_batch = []
        for element in self.dataset:
            self.num_examples += 1
            current_batch.append(element)
            # Wait to have a full batch before yielding elements.
            if len(current_batch) == self.batch_size:
                for batch in current_batch:
                    yield batch
                    if first_batch is None:
                        first_batch = batch.copy()
                current_batch = []

        while self.num_examples < self.length:
            add_num = self.batch_size - len(current_batch)
            self.num_examples += add_num
            current_batch += [first_batch] * add_num
            for batch in current_batch:
                yield batch
            current_batch = []

# %% [markdown]
# #### 전처리된 데이터를 DataLoader로 불러옴

# %%
import torch.utils.data as torch_data

def collate_fn(features):
    input_ids = [sample["input_ids"] for sample in features]
    attention_mask = [sample["attention_mask"] for sample in features]
    government = [sample["government"] for sample in features]  # 'politic'을 'government'로 변경

    input_ids = torch.tensor(np.array(input_ids).astype(np.int64), dtype=torch.long)
    attention_mask = torch.tensor(np.array(attention_mask).astype(np.int8), dtype=torch.long)
    government = torch.tensor(np.array(government).astype(np.int64), dtype=torch.long)  # 'politic'을 'government'로 변경

    inputs = {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
    }
    labels = {
        "government": government  # 'politic'을 'government'로 변경
    }
    return inputs, labels

# 본 코드에서 학습을 수행하려는 경우
if config.do_train:
    # 학습 데이터 로더 초기화
    train_dataset = load_dataset("text", data_files=train_dataset_file, download_mode="force_redownload")["train"]
    train_dataset = train_dataset.map(lambda x: json.loads(x["text"]), batched=False)

    train_dataloader = torch_data.DataLoader(
        train_dataset,
        sampler=torch_data.RandomSampler(train_dataset),
        drop_last=False,
        batch_size=config.train_batch_size,
        collate_fn=(collate_fn),
    )

# 검증 데이터 세트 전처리(validation)
valid_dataset = load_dataset("text", data_files=valid_dataset_file, download_mode="force_redownload")["train"]
valid_dataset = valid_dataset.map(lambda x: json.loads(x["text"]), batched=False)
valid_dataset = IterableDatasetPad(
    dataset=valid_dataset,
    batch_size=config.eval_batch_size,
    num_devices=1,
    seed=config.seed,
)

valid_dataloader = torch_data.DataLoader(
    valid_dataset,
    sampler=None,
    drop_last=False,
    batch_size=config.eval_batch_size,
    collate_fn=(collate_fn),
)

# 테스트 데이터 세트 로딩 및 전처리
test_dataset = load_dataset("text", data_files=test_dataset_file, download_mode="force_redownload")["train"]
test_dataset = test_dataset.map(lambda x: json.loads(x["text"]), batched=False)
test_dataset = IterableDatasetPad(
    dataset=test_dataset,
    batch_size=config.eval_batch_size,
    num_devices=1,
    seed=config.seed,
)

test_dataloader = torch_data.DataLoader(
    test_dataset,
    sampler=None,
    drop_last=False,
    batch_size=config.eval_batch_size,
    collate_fn=(collate_fn),
)
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]

# %% [markdown]
# ### 텍스트 분류 모델 정의

# %%
from transformers import AutoModel
import torch.nn as nn

# 텍스트 분류 모델 정의
class ClsModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        # (전처리된) 학습할 데이터 세트의 경로 설정
        data_file = os.path.join(config.data_dir, str(config.train_file))
        # 사전 학습된 모델 가중치 불러오기
        model_config = AutoConfig.from_pretrained(config.model_name_or_path, num_labels=config.num_labels)
        self.model = AutoModel.from_pretrained(
            config.model_name_or_path, config=model_config, cache_dir=config.cache_dir
        )
        self.classifier1 = nn.Linear(768, 6)

        # BERT model과 별개로, 입력 문자열을 토큰의 index로 바꾸어주는 tokenizer가 사용됨
        self.tokenizer = tokenizer

    # "학습된 모델"을 save_dir에 저장하는 함수
    def save_pretrained(self, save_dir):
        self.model.save_pretrained(save_dir)
        # Tokenizer는 기본적으로 "special_tokens_map_file", "tokenizer_file"을 가질 수 있음
        # 이러한 값을 제거한 뒤에 save_dir에 저장하겠다는 의미
        for key in ["special_tokens_map_file", "tokenizer_file"]:
            self.tokenizer.init_kwargs.pop(key, None)
        self.tokenizer.save_pretrained(save_dir)

    def get_optimizer(self):
        no_decay = ["bias", "LayerNorm.weight"]
        optimizer_grouped_parameters = [
            {
                "params": [p for n, p in self.model.named_parameters() if not any(nd in n for nd in no_decay)],
                "weight_decay": config.weight_decay,
            }
        ]
        optimizer = AdamW(optimizer_grouped_parameters, lr=config.learning_rate, eps=config.adam_epsilon)
        return optimizer

    def get_scheduler(self, batch_num, optimizer):  # AdamW로 학습할 때, learning rate을 단계적으로 줄이기 위한 함수
        if config.warmup_proportion == 0.0:
            return None

        t_total = batch_num // config.gradient_accumulation_steps * config.num_train_epochs

        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=int(t_total * config.warmup_proportion),
            num_training_steps=t_total,
        )

        return scheduler

    def forward(self, inputs):
        hidden = self.model(**inputs)
        cls_token_embeddings = hidden.last_hidden_state[:, 0, :]
        output_2 = self.classifier1(cls_token_embeddings)  # Renamed: output_1 -> output_2
        return output_2

    def eval_step(self, inputs, labels, outputs_2):  # Renamed: outputs -> outputs_2
        logits_2 = outputs_2.detach().cpu()  # Renamed: logits_1 -> logits_2
        labels_2 = self.tensor_to_list(labels["government"])  # Renamed: labels_1 -> labels_2 & "government" -> "2"
        predictions_2 = self.tensor_to_list(torch.argmax(logits_2, dim=-1))  # Renamed: predictions_1 -> predictions_2
        results_2 = [{"prediction": prediction, "label": label} for prediction, label in zip(predictions_2, labels_2)]  # Renamed: results_1 -> results_2
        return {"results_2": results_2}  # Renamed: results_1 -> results_2


    # PyTorch의 Tensor 객체를 NumPy 객체로 변환
    def tensor_to_array(self, tensor):
        return tensor.detach().cpu().numpy()

    # PyTorch의 Tensor 객체를 Python의 리스트(list) 자료형으로 변환
    def tensor_to_list(self, tensor):
        return self.tensor_to_array(tensor).tolist()

# %%
def set_seed(seed):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

def cal_running_avg_loss(loss, running_avg_loss, decay=0.99):
    if running_avg_loss == 0:
        return loss
    running_avg_loss = running_avg_loss * decay + (1 - decay) * loss
    return running_avg_loss

# %% [markdown]
# ### 모델 학습 및 평가 라이브러리

# %%
from functools import partial
import sklearn.metrics as sklearn_metrics

metrics = {
    "accuracy": sklearn_metrics.accuracy_score,
    "f1-macro": partial(sklearn_metrics.f1_score, average="macro"),
}

def eval_cls(results_2, **kwargs):
    predictions_2 = np.array([result["prediction"] for result in results_2])
    labels_2 = np.array([result["label"] for result in results_2])

    results_2_metrics = {
        metric: round(f(labels_2, predictions_2) * 100, 2)
        for metric, f in metrics.items()
    }

    return {
        "results_2": results_2_metrics,
        "best_score_2": results_2_metrics["f1-macro"],
    }

# %% [markdown]
# ### Epoch 동안 학습 및 평가를 수행하는 함수 정의

# %%
def _run_epoch(model, loader, device=None, context=None, **kwargs):
    config = kwargs["config"]
    is_train = kwargs["is_train"]

    avg_loss = 0
    results = []
    batch_num = len(loader)

    if is_train:
        model.train()
        if config.use_tpu:
            optimizer = context.getattr_or("optimizer", lambda: model.get_optimizer())
            scheduler = context.getattr_or("scheduler", lambda: model.get_scheduler(batch_num, optimizer))
        else:
            optimizer = kwargs["optimizer"]
            scheduler = kwargs["scheduler"]
    else:
        model.eval()

    is_master = True

    pbar = tqdm(enumerate(loader), total=batch_num, disable=not is_master, dynamic_ncols=True, position=0, leave=True)

    corrected_2 = 0
    total = 0

    for i, (inputs, labels) in pbar:
        for k, v in inputs.items():
            if isinstance(v, torch.Tensor):
                inputs[k] = v.to(device)
        for k, v in labels.items():
            if isinstance(v, torch.Tensor):
                labels[k] = v.to(device)

        outputs_2 = model(inputs)
        labels_2 = labels["government"]

        loss_function_2 = nn.CrossEntropyLoss()
        loss_2 = loss_function_2(outputs_2, labels_2)

        total += outputs_2.shape[0]
        _, predicted_2 = outputs_2.max(1)
        corrected_2 += predicted_2.eq(labels_2).sum().item()

        accuracy = corrected_2 / total * 100
        avg_loss = cal_running_avg_loss(loss_2.item(), avg_loss)
        loss_2 /= config.gradient_accumulation_steps

        if is_train:
            loss_2.backward()
            if i % config.gradient_accumulation_steps == 0 or i == batch_num - 1:
                if config.max_grad_norm > 0:
                    torch.nn.utils.clip_grad_norm_(model.parameters(), config.max_grad_norm)

                optimizer.step()
                optimizer.zero_grad()

                if scheduler is not None:
                    scheduler.step()
        else:
            result = (model.module if hasattr(model, "module") else model).eval_step(inputs, labels, outputs_2)
            results.append(result)

        if is_master:
            pbar.set_description(f"epoch: {kwargs['epoch'] + 1}, {('train' if is_train else 'valid')} loss: {min(100, round(avg_loss, 4))}")

    return {
        "loss": avg_loss,
        "result": results,
        "accuracy":accuracy
    }



# 학습 코드에서 호출하는 함수
def run_epoch(**kwargs):
    model = kwargs.pop("model")
    if kwargs["config"].use_tpu:
        results = model(_run_epoch, **kwargs)
    else:
        results = _run_epoch(model, **kwargs)

    if isinstance(results, list):
        loss = sum([result["loss"] for result in results]) / len(results)
        result = []
        for res in results:
            result.extend(res["result"])
        results = {"loss": loss, "result": result}

    return results

# %% [markdown]
# ### 딥러닝 모델 초기화 및 설정

# %%
set_seed(config.seed)

model = ClsModel()

print(f"configuration: {str(config)}")

if torch.cuda.is_available(): # GPU를 사용할 수 있다면
    gpu_count = torch.cuda.device_count()
    print(f"{gpu_count} GPU device detected")
    devices = ["cuda:{}".format(i) for i in range(gpu_count)]
    model_dp = torch.nn.DataParallel(model, device_ids=devices)
    model.to(devices[0])
else: # GPU를 사용할 수 없다면 CPU로 구동
    devices = ["cpu"]
    model_dp = model

# 학습 결과를 저장하기 위한 폴더 만들기
if not os.path.exists(config.cache_dir):
    os.makedirs(config.cache_dir)

output_dir = os.path.join(config.output_dir, config.task, config.dataset)
print("Output directory:", output_dir)
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 실제 학습을 위해 optimizer 및 scheduler 초기화
optimizer = None
scheduler = None
if config.do_train: # 학습 모드(train mode)인 경우
    optimizer = model.get_optimizer()
    scheduler = model.get_scheduler(len(train_dataloader), optimizer)

params = {
    "config": config,
    "model": model_dp,
    "optimizer": optimizer,
    "scheduler": scheduler,
}
if not config.use_tpu:
    params["device"] = devices[0]
# Out:
# Downloading model.safetensors:   0%|          | 0.00/458M [00:00<?, ?B/s]
# configuration: namespace(task='cls', dataset='comment', cache_dir='cache', output_dir='output', use_tpu=False, model_name_or_path='monologg/kobigbird-bert-base', data_dir='./', train_file='complete_train.csv', test_file='complete_test.csv', max_seq_length=1024, train_batch_size=4, eval_batch_size=2, learning_rate=3e-05, num_train_epochs=20, num_labels=5, gradient_accumulation_steps=2, threads=4, seed=42, do_train=True, do_eval_during_train=True, do_eval=True, do_lower_case=False, weight_decay=0.0, adam_epsilon=1e-08, max_grad_norm=1.0, warmup_proportion=0.0)
# 1 GPU device detected
# Output directory: output/cls/comment

# %%
# 수정된 do_eval

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_f1_scores = []
val_f1_scores = []

def do_eval(epoch):
    with torch.no_grad():
        eval_run_results = run_epoch(loader=valid_dataloader, epoch=epoch, is_train=False, **params)
        results = eval_run_results["result"]
        val_loss = eval_run_results['loss']  # 이 부분은 run_epoch의 반환값에 따라 수정할 필요가 있을 수 있습니다.
        val_losses.append(val_loss)

        results_2 = [result['results_2'] for result in results]
        results_2 = [item for sublist in results_2 for item in sublist]

        eval_results = eval_cls(results_2=results_2)

        # f1-score을 저장합니다.
        # 이 부분은 eval_cls의 반환 값에 따라서 조정해야 할 수 있습니다.
        #val_f1 = eval_results["results_1"].get('f1-macro', 0)
        #val_f1_scores.append(val_f1)

    print("Eval results for output 2.")
    for k, v in eval_results["results_2"].items():
        print(f"{k} : {v}")

    return eval_results["best_score_2"], eval_results

best_model_path = "best_model.pth"

# 학습 코드
if config.do_train:
    best_score = 0
    for epoch in range(config.num_train_epochs):
        train_results = run_epoch(loader=train_dataloader, epoch=epoch, is_train=True, **params)
        train_loss = train_results['loss']
        train_losses.append(train_loss)

        # train f1 score 및 accuracy를 리스트에 저장합니다.
        # 이 부분은 run_epoch의 반환 값에 따라서 조정해야 할 수 있습니다.
        train_accuracies.append(train_results.get('accuracy', 0))

        if config.do_eval_during_train:
            score, eval_results = do_eval(epoch)
            val_accuracies.append(score)
            f1_score_2 = eval_results["results_2"].get("f1-macro", 0)
            val_f1_scores.append(f1_score_2)

            # Save the model if the score is better
            if score > best_score:
                best_score = score

                # Save the model weights to best_model_path
                if hasattr(model_dp, "module"):
                    torch.save(model_dp.module.state_dict(), best_model_path)
                elif hasattr(model_dp, "_models"):
                    torch.save(model_dp._models[0].state_dict(), best_model_path)
                else:
                    torch.save(model_dp.state_dict(), best_model_path)

                print(f"Best model saved to {best_model_path}.")
# Out:
# epoch: 1, train loss: 1.1024: 100%|██████████| 1000/1000 [10:07<00:00,  1.65it/s]
# epoch: 1, valid loss: 1.0464: 100%|██████████| 251/251 [00:32<00:00,  7.83it/s]
# Eval results for output 2.
# accuracy : 57.97
# f1-macro : 41.42
# Best model saved to best_model.pth.
# epoch: 2, train loss: 0.9205: 100%|██████████| 1000/1000 [10:06<00:00,  1.65it/s]
# epoch: 2, valid loss: 0.9009: 100%|██████████| 251/251 [00:32<00:00,  7.81it/s]
# Eval results for output 2.
# accuracy : 61.95
# f1-macro : 49.41
# Best model saved to best_model.pth.
# epoch: 3, train loss: 0.7629: 100%|██████████| 1000/1000 [10:04<00:00,  1.65it/s]
# epoch: 3, valid loss: 0.9272: 100%|██████████| 251/251 [00:32<00:00,  7.74it/s]
# Eval results for output 2.
# accuracy : 61.95
# f1-macro : 54.87
# Best model saved to best_model.pth.
# epoch: 4, train loss: 0.5208: 100%|██████████| 1000/1000 [10:04<00:00,  1.66it/s]
# epoch: 4, valid loss: 1.2931: 100%|██████████| 251/251 [00:32<00:00,  7.76it/s]
# Eval results for output 2.
# accuracy : 61.75
# f1-macro : 51.15
# epoch: 5, train loss: 0.466: 100%|██████████| 1000/1000 [10:04<00:00,  1.65it/s]
# epoch: 5, valid loss: 1.3449: 100%|██████████| 251/251 [00:32<00:00,  7.72it/s]
# Eval results for output 2.
# accuracy : 60.76
# f1-macro : 51.24
# epoch: 6, train loss: 0.2956: 100%|██████████| 1000/1000 [10:06<00:00,  1.65it/s]
# epoch: 6, valid loss: 1.709: 100%|██████████| 251/251 [00:32<00:00,  7.70it/s]
# Eval results for output 2.
# accuracy : 62.35
# f1-macro : 54.0
# epoch: 7, train loss: 0.2243: 100%|██████████| 1000/1000 [10:05<00:00,  1.65it/s]
# epoch: 7, valid loss: 2.3106: 100%|██████████| 251/251 [00:32<00:00,  7.76it/s]
# Eval results for output 2.
# accuracy : 56.18
# f1-macro : 47.42
# epoch: 8, train loss: 0.1806: 100%|██████████| 1000/1000 [10:05<00:00,  1.65it/s]
# epoch: 8, valid loss: 2.0583: 100%|██████████| 251/251 [00:32<00:00,  7.72it/s]
# Eval results for output 2.
# accuracy : 57.57
# f1-macro : 51.41
# epoch: 9, train loss: 0.0816: 100%|██████████| 1000/1000 [10:04<00:00,  1.65it/s]
# epoch: 9, valid loss: 2.1584: 100%|██████████| 251/251 [00:32<00:00,  7.77it/s]
# Eval results for output 2.
# accuracy : 62.15
# f1-macro : 53.06
# epoch: 10, train loss: 0.1085: 100%|██████████| 1000/1000 [10:05<00:00,  1.65it/s]
# epoch: 10, valid loss: 2.1345: 100%|██████████| 251/251 [00:32<00:00,  7.77it/s]
# Eval results for output 2.
# accuracy : 62.95
# f1-macro : 50.32
# epoch: 11, train loss: 0.0725: 100%|██████████| 1000/1000 [10:05<00:00,  1.65it/s]
# epoch: 11, valid loss: 2.4019: 100%|██████████| 251/251 [00:32<00:00,  7.72it/s]
# Eval results for output 2.
# accuracy : 59.36
# f1-macro : 48.8
# epoch: 12, train loss: 0.0941: 100%|██████████| 1000/1000 [10:05<00:00,  1.65it/s]
# epoch: 12, valid loss: 2.4671: 100%|██████████| 251/251 [00:32<00:00,  7.79it/s]
# Eval results for output 2.
# accuracy : 60.36
# f1-macro : 50.46
# epoch: 13, train loss: 0.0674: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 13, valid loss: 2.2681: 100%|██████████| 251/251 [00:32<00:00,  7.80it/s]
# Eval results for output 2.
# accuracy : 63.94
# f1-macro : 54.34
# epoch: 14, train loss: 0.1535: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 14, valid loss: 2.4208: 100%|██████████| 251/251 [00:32<00:00,  7.80it/s]
# Eval results for output 2.
# accuracy : 60.96
# f1-macro : 49.94
# epoch: 15, train loss: 0.1238: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 15, valid loss: 2.5415: 100%|██████████| 251/251 [00:32<00:00,  7.73it/s]
# Eval results for output 2.
# accuracy : 59.36
# f1-macro : 51.74
# epoch: 16, train loss: 0.1248: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 16, valid loss: 2.4294: 100%|██████████| 251/251 [00:32<00:00,  7.80it/s]
# Eval results for output 2.
# accuracy : 59.36
# f1-macro : 51.07
# epoch: 17, train loss: 0.069: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 17, valid loss: 2.5469: 100%|██████████| 251/251 [00:32<00:00,  7.76it/s]
# Eval results for output 2.
# accuracy : 59.36
# f1-macro : 49.29
# epoch: 18, train loss: 0.1023: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 18, valid loss: 2.6458: 100%|██████████| 251/251 [00:32<00:00,  7.79it/s]
# Eval results for output 2.
# accuracy : 60.16
# f1-macro : 46.81
# epoch: 19, train loss: 0.0836: 100%|██████████| 1000/1000 [10:04<00:00,  1.66it/s]
# epoch: 19, valid loss: 2.6943: 100%|██████████| 251/251 [00:32<00:00,  7.79it/s]
# Eval results for output 2.
# accuracy : 57.37
# f1-macro : 48.62
# epoch: 20, train loss: 0.0832: 100%|██████████| 1000/1000 [10:03<00:00,  1.66it/s]
# epoch: 20, valid loss: 2.8547: 100%|██████████| 251/251 [00:32<00:00,  7.77it/s]
# Eval results for output 2.
# accuracy : 56.97
# f1-macro : 45.14

# %%
import matplotlib.pyplot as plt

epochs = range(1, config.num_train_epochs + 1)

plt.figure(figsize=(18, 4))  # 크기 조절

# Loss plot
plt.subplot(1, 3, 1)
plt.plot(epochs, train_losses, 'r', label='Training loss')
plt.plot(epochs, val_losses, 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 3, 2)
plt.plot(epochs, train_accuracies, 'r', label='Training Accuracy')
plt.plot(epochs, val_accuracies, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# F1 Score plot 추가
plt.subplot(1, 3, 3)
plt.plot(val_f1_scores, 'b', label='Validation F1 Score')
plt.title('Validation F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score, f1_score

# Load model weights
model.load_state_dict(torch.load(best_model_path))
model.to(devices[0])  # Move the model to GPU if necessary
model.eval()

all_predictions_2 = []
all_top2_predictions_2 = []
all_labels_2 = []

# Evaluate the test_dataset
with torch.no_grad():
    for inputs, labels in test_dataloader:
        for k, v in inputs.items():
            if isinstance(v, torch.Tensor):
                inputs[k] = v.to(devices[0])
        for k, v in labels.items():
            if isinstance(v, torch.Tensor):
                labels[k] = v.to(devices[0])

        outputs_2 = model(inputs)
        _, predicted_2 = outputs_2.topk(2, dim=1)

        all_predictions_2.extend(predicted_2[:, 0].cpu().tolist())
        all_top2_predictions_2.extend(predicted_2.cpu().tolist())
        all_labels_2.extend(labels["government"].cpu().tolist())

        # Print the actual values and predicted values
        for true_label_2, pred_label_2 in zip(labels["government"].cpu().tolist(), predicted_2[:, 0].cpu().tolist()):
            print(f"Output 2 - True Label: {true_label_2}, Predicted: {pred_label_2}")

# Calculate accuracy and f1-score
accuracy_2 = accuracy_score(all_labels_2, all_predictions_2)
f1_2 = f1_score(all_labels_2, all_predictions_2, average='macro')

# Calculate Top-2 Accuracy
top2_correct = sum([true_label in pred_labels for true_label, pred_labels in zip(all_labels_2, all_top2_predictions_2)])
top2_accuracy_2 = top2_correct / len(all_labels_2)

print(f"\nOutput 2 - Accuracy: {accuracy_2:.4f}, F1 Score: {f1_2:.4f}, Top-2 Accuracy: {top2_accuracy_2:.4f}")
# Out:
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 4
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 0
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 2, Predicted: 3
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 1, Predicted: 3
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 2, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 3, Predicted: 2
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 2, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 2
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 1
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 3
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 4, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 2, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 2
# Output 2 - True Label: 4, Predicted: 0
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 2
# Output 2 - True Label: 3, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 3, Predicted: 2
# Output 2 - True Label: 5, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 4, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 5, Predicted: 3
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 4, Predicted: 1
# Output 2 - True Label: 3, Predicted: 5
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 2
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 3, Predicted: 5
# Output 2 - True Label: 4, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 4
# Output 2 - True Label: 4, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 2, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 1
# Output 2 - True Label: 4, Predicted: 1
# Output 2 - True Label: 1, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 3
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 2
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 5, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 3, Predicted: 4
# Output 2 - True Label: 0, Predicted: 1
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 4, Predicted: 0
# Output 2 - True Label: 3, Predicted: 3
# Output 2 - True Label: 4, Predicted: 5
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 3, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 2, Predicted: 2
# Output 2 - True Label: 4, Predicted: 4
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 0, Predicted: 4
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 5, Predicted: 0
# Output 2 - True Label: 5, Predicted: 1
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 0, Predicted: 0
# Output 2 - True Label: 4, Predicted: 0
# Output 2 - True Label: 5, Predicted: 4
# Output 2 - True Label: 5, Predicted: 0
# Output 2 - True Label: 5, Predicted: 5
# Output 2 - True Label: 5, Predicted: 2
# Output 2 - True Label: 1, Predicted: 1
# Output 2 - True Label: 1, Predicted: 1
#
# Output 2 - Accuracy: 0.6235, F1 Score: 0.5516, Top-2 Accuracy: 0.8048
